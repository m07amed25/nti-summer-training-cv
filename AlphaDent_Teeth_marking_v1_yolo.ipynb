# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.8.3)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c alpha-dent
# Out:
# Downloading alpha-dent.zip to /content
# 100% 4.55G/4.56G [01:00<00:00, 123MB/s]
# 100% 4.56G/4.56G [01:00<00:00, 80.4MB/s]

# %%
# !unzip alpha-dent.zip -d ./alpha_dent_data
# Out:
# Archive:  alpha-dent.zip
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_000.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_009.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_010.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_011.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_012.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_013.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_014.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_015.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_016.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_017.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_018.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_019.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_020.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_021.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_022.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_023.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_024.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_025.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_026.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_027.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_028.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_029.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_030.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_031.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_032.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_033.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_034.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_035.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_036.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_037.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_038.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_039.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_040.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_041.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_042.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_043.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_044.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_045.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_046.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_047.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_048.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_049.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_050.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_051.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_052.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_053.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_054.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_055.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_056.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_057.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_058.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_059.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_060.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_061.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_062.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_063.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_064.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_065.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_066.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_067.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_068.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_069.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_070.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_071.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_072.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_073.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_074.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_075.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_076.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_077.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_078.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_079.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_080.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_081.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_082.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_083.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_084.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_085.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_086.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_087.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_088.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_089.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_090.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_091.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_092.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_093.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_094.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_095.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_096.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_097.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_098.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_099.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_100.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_101.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_102.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_103.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_104.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_105.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_106.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_107.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_108.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_109.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_110.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_111.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_112.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_113.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_114.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_115.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_116.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_117.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_118.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_119.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_120.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_121.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_122.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_123.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_124.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_125.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_126.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_127.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_128.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_129.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_130.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_131.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_132.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_133.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/test/test_134.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p002_F_52_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p002_F_52_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p002_F_52_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p002_F_52_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p002_F_52_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p003_M_27_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p003_M_27_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p004_M_34_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p004_M_34_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p004_M_34_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p005_M_51_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p005_M_51_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p005_M_51_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p006_F_15_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p006_F_15_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p006_F_15_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p007_M_51_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p007_M_51_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p007_M_51_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p008_M_26_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p008_M_26_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p008_M_26_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p009_M_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p009_M_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p009_M_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p010_M_34_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p010_M_34_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p010_M_34_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p010_M_34_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p010_M_34_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p011_M_59_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p011_M_59_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p011_M_59_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p012_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p012_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p012_F_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p013_M_37_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p013_M_37_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p013_M_37_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p014_F_46_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p014_F_46_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p014_F_46_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p014_F_46_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p016_M_37_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p016_M_37_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p016_M_37_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p017_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p017_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p017_F_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p018_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p018_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p018_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p019_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p019_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p019_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p020_F_42_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p020_F_42_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p020_F_42_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p020_F_42_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p021_M_49_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p022_F_28_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p022_F_28_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p022_F_28_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p023_F_22_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p023_F_22_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p023_F_22_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p024_F_52_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p024_F_52_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p024_F_52_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p025_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p025_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p027_M_50_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p027_M_50_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p027_M_50_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p027_M_50_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p028_F_44_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p028_F_44_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p028_F_44_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p029_F_30_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p029_F_30_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p030_M_31_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p030_M_31_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p030_M_31_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p031_M_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p031_M_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p032_F_38_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p032_F_38_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p032_F_38_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p033_M_61_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p033_M_61_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p033_M_61_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p033_M_61_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p033_M_61_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p035_F_28_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p035_F_28_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p035_F_28_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p037_M_49_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p037_M_49_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p037_M_49_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p038_F_35_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p038_F_35_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p038_F_35_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p039_M_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p039_M_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p039_M_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p040_M_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p040_M_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p040_M_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p041_F_48_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p041_F_48_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p041_F_48_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p042_F_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p042_F_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p042_F_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p043_F_24_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p043_F_24_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p043_F_24_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p045_M_10_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p045_M_10_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p046_M_25_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p046_M_25_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p046_M_25_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p047_M_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p047_M_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p047_M_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p048_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p048_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p048_F_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p049_M_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p049_M_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p049_M_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p050_M_44_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p050_M_44_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p050_M_44_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p051_M_21_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p051_M_21_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p051_M_21_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p052_M_11_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p052_M_11_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p052_M_11_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p053_M_08_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p054_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p054_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p054_F_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p055_F_23_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p055_F_23_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p055_F_23_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p057_M_37_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p057_M_37_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p057_M_37_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p058_M_53_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p058_M_53_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p058_M_53_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p059_M_13_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p059_M_13_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p059_M_13_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p060_M_29_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p060_M_29_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p060_M_29_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p061_M_18_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p061_M_18_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p061_M_18_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p062_M_35_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p062_M_35_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p062_M_35_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p063_F_51_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p063_F_51_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p063_F_51_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p064_F_62_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p064_F_62_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p064_F_62_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p065_F_51_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p065_F_51_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p065_F_51_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p067_M_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p067_M_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p067_M_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p068_F_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p068_F_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p068_F_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p070_M_38_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p070_M_38_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p070_M_38_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p071_M_44_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p071_M_44_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p071_M_44_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p072_F_26_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p072_F_26_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p072_F_26_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p073_F_38_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p073_F_38_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p073_F_38_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p074_M_27_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p074_M_27_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p074_M_27_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p075_F_28_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p075_F_28_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p075_F_28_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p076_F_13_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p076_F_13_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p076_F_13_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p077_F_43_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p077_F_43_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p077_F_43_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p079_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p079_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p079_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p080_F_45_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p080_F_45_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p080_F_45_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p081_F_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p081_F_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p081_F_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p082_M_39_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p082_M_39_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p082_M_39_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p083_F_26_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p083_F_26_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p083_F_26_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p084_M_36_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p084_M_36_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p084_M_36_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p085_F_41_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p085_F_41_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p085_F_41_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p086_F_26_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p086_F_26_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p086_F_26_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p087_F_42_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p087_F_42_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p087_F_42_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p088_M_29_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p088_M_29_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p088_M_29_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p089_F_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p089_F_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p089_F_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p090_F_47_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p090_F_47_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p090_F_47_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p091_F_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p091_F_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p091_F_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p092_F_43_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p092_F_43_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p092_F_43_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p093_F_18_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p093_F_18_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p093_F_18_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p094_F_30_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p094_F_30_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p094_F_30_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p095_M_30_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p095_M_30_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p095_M_30_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p096_F_58_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p096_F_58_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p096_F_58_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p098_M_60_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p098_M_60_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p098_M_60_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p099_F_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p099_F_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p099_F_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p100_F_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p100_F_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p100_F_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p102_F_47_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p102_F_47_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p102_F_47_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p103_M_25_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p103_M_25_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p103_M_25_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p104_M_21_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p104_M_21_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p104_M_21_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p105_M_44_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p105_M_44_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p105_M_44_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p106_F_41_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p106_F_41_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p106_F_41_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p107_M_41_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p107_M_41_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p107_M_41_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p108_M_41_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p108_M_41_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p108_M_41_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p109_F_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p109_F_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p109_F_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p110_F_35_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p110_F_35_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p110_F_35_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p111_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p111_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p111_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p112_F_24_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p112_F_24_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p112_F_24_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p112_F_24_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p113_F_41_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p114_M_32_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p115_F_31_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p116_M_33_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p117_M_44_009.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_009.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p118_F_45_010.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p119_F_31_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p119_F_31_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p119_F_31_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p119_F_31_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p120_F_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p120_F_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p120_F_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p121_M_32_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p122_F_34_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p122_F_34_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p122_F_34_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p122_F_34_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p123_F_30_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p123_F_30_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p124_M_29_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p125_M_34_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p126_M_33_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p127_F_46_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p127_F_46_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p127_F_46_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p127_F_46_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p128_F_47_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p128_F_47_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p128_F_47_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p128_F_47_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p128_F_47_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p129_M_35_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p129_M_35_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p129_M_35_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p129_M_35_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p129_M_35_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p130_M_48_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p130_M_48_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p131_F_31_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_009.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_010.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_011.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_012.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p132_M_25_013.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p133_M_34_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p134_M_54_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p134_M_54_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p134_M_54_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p135_F_37_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p136_F_54_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p136_F_54_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p136_F_54_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p137_M_37_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p137_M_37_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p137_M_37_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p137_M_37_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p138_M_20_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p139_M_45_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p139_M_45_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p140_F_38_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p140_F_38_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p140_F_38_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p140_F_38_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p140_F_38_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p141_M_33_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p142_F_29_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p142_F_29_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p142_F_29_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p142_F_29_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p142_F_29_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p143_F_29_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p143_F_29_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p143_F_29_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p144_F_27_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p145_M_53_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p145_M_53_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p146_M_39_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p146_M_39_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p147_F_28_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p147_F_28_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p147_F_28_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p148_F_31_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p148_F_31_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p148_F_31_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p148_F_31_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p149_M_14_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p149_M_14_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p149_M_14_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p149_M_14_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p149_M_14_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p150_F_40_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p151_F_18_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p151_F_18_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p151_F_18_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p151_F_18_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_001.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_002.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_003.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_004.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_005.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_006.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_007.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_008.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p152_M_28_009.jpg
#   inflating: ./alpha_dent_data/AlphaDent/images/train/p153_F_42_001.jpg
# ...
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p264_F_27_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_009.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p265_F_48_010.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p267_M_28_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p268_M_30_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p268_M_30_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p268_M_30_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p268_M_30_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p268_M_30_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p269_F_62_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p270_F_30_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p271_M_32_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p272_M_32_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p272_M_32_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p273_F_30_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p273_F_30_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p273_F_30_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p273_F_30_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p274_F_50_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p276_F_28_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p276_F_28_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p276_F_28_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p277_F_34_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p277_F_34_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p277_F_34_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p277_F_34_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p277_F_34_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p278_F_18_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p278_F_18_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p278_F_18_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p279_M_28_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p279_M_28_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p279_M_28_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p279_M_28_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p280_M_40_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p280_M_40_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p280_M_40_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p280_M_40_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p281_F_27_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_009.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_010.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_011.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p282_F_38_012.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p284_F_37_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p284_F_37_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p286_M_40_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p287_F_20_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p288_F_36_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p288_F_36_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p289_F_36_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p289_F_36_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p289_F_36_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p289_F_36_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p290_M_38_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p290_M_38_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p290_M_38_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p290_M_38_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p290_M_38_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p291_F_28_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p292_F_36_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p292_F_36_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/train/p293_F_35_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p001_F_51_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p001_F_51_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p001_F_51_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p001_F_51_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p015_M_53_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p015_M_53_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p015_M_53_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p015_M_53_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p026_F_34_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p026_F_34_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p026_F_34_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p034_F_17_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p034_F_17_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p034_F_17_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p036_M_13_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p036_M_13_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p036_M_13_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p036_M_13_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p044_F_35_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p044_F_35_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p044_F_35_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p056_F_60_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p056_F_60_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p056_F_60_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p066_M_34_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p066_M_34_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p066_M_34_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p069_M_11_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p069_M_11_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p069_M_11_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p078_F_38_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p078_F_38_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p078_F_38_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p097_F_43_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p097_F_43_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p097_F_43_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p101_F_24_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p101_F_24_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p101_F_24_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p179_M_52_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p179_M_52_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p220_F_28_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p220_F_28_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p220_F_28_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p235_F_27_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p235_F_27_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p241_F_24_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p241_F_24_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p241_F_24_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p255_M_38_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p255_M_38_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p255_M_38_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_007.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_008.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_009.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_010.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_011.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p261_F_31_012.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p266_M_32_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p266_M_32_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p266_M_32_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p266_M_32_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p266_M_32_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p275_M_27_006.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p283_M_26_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p283_M_26_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p283_M_26_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p283_M_26_004.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p283_M_26_005.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p285_F_19_001.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p285_F_19_002.txt
#   inflating: ./alpha_dent_data/AlphaDent/labels/valid/p285_F_19_003.txt
#   inflating: ./alpha_dent_data/AlphaDent/yolo_seg_train.yaml
#   inflating: ./alpha_dent_data/sample_submission.csv

# %% [markdown]
# ---

# %%
# !pip install -q ultralytics

# %%
import os
import sys
import time
import glob
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from tqdm.auto import tqdm
import yaml
import random
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

os.environ['WANDB_DISABLED'] = 'true'

random.seed(42)
np.random.seed(42)

os.system('pip install -q ultralytics')

import torch
from ultralytics import YOLO

torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
print(f'\nPyTorch Version: {torch.__version__}')
print(f'CUDA Available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'CUDA Device: {torch.cuda.get_device_name(0)}')
# Out:
# PyTorch Version: 2.6.0+cu124
# CUDA Available: True
# CUDA Device: Tesla T4

# %%
BASE_PATH = '/content/alpha_dent_data/AlphaDent'
TRAIN_IMAGES_PATH = f'{BASE_PATH}/images/train'
VALID_IMAGES_PATH = f'{BASE_PATH}/images/valid'
TEST_IMAGES_PATH = f'{BASE_PATH}/images/test'
TRAIN_LABELS_PATH = f'{BASE_PATH}/labels/train'
VALID_LABELS_PATH = f'{BASE_PATH}/labels/valid'

OUTPUT_DIR = '/content/'
WEIGHTS_DIR = f'{OUTPUT_DIR}/weights'
os.makedirs(WEIGHTS_DIR, exist_ok=True)

# %%
CLASS_INFO = {
    0: {'name': 'Abrasion', 'description': 'Teeth with mechanical wear of hard tissues'},
    1: {'name': 'Filling', 'description': 'Dental fillings of various types'},
    2: {'name': 'Crown', 'description': 'Dental crown (restoration)'},
    3: {'name': 'Caries Class 1', 'description': 'Caries in fissures and pits'},
    4: {'name': 'Caries Class 2', 'description': 'Caries on proximal surfaces of molars/premolars'},
    5: {'name': 'Caries Class 3', 'description': 'Caries on proximal surfaces of incisors/canines without incisal edge'},
    6: {'name': 'Caries Class 4', 'description': 'Caries on proximal surfaces of incisors/canines with incisal edge'},
    7: {'name': 'Caries Class 5', 'description': 'Cervical caries (buccal/lingual surfaces)'},
    8: {'name': 'Caries Class 6', 'description': 'Caries on incisal edges or cusps'}
}

# %%
yolo_config = {
    'path': BASE_PATH,
    'train': 'images/train',
    'val': 'images/valid',
    'test': 'images/test',
    'nc': 9,
    'names': [CLASS_INFO[i]['name'] for i in range(9)]
}

# %%
CUSTOM_YAML_PATH = f'{OUTPUT_DIR}/alphadent_config.yaml'
with open(CUSTOM_YAML_PATH, 'w') as f:
    yaml.dump(yolo_config, f, default_flow_style=False)
print(f"Created custom YAML config at: {CUSTOM_YAML_PATH}")
# Out:
# Created custom YAML config at: /content//alphadent_config.yaml

# %%
train_images = sorted(glob.glob(f'{TRAIN_IMAGES_PATH}/*.jpg'))
valid_images = sorted(glob.glob(f'{VALID_IMAGES_PATH}/*.jpg'))
test_images = sorted(glob.glob(f'{TEST_IMAGES_PATH}/*.jpg'))

# %%
def analyze_class_distribution(labels_path):
    """Analyze class distribution in dataset."""
    class_counts = {i: 0 for i in range(9)}
    total_annotations = 0

    label_files = glob.glob(f'{labels_path}/*.txt')

    for label_file in tqdm(label_files, desc="Analyzing labels", leave=False):
        if os.path.exists(label_file) and os.path.getsize(label_file) > 0:
            try:
                with open(label_file, 'r') as f:
                    lines = f.readlines()
                    for line in lines:
                        if line.strip():
                            parts = line.strip().split()
                            if parts:
                                class_id = int(parts[0])
                                if 0 <= class_id < 9:
                                    class_counts[class_id] += 1
                                    total_annotations += 1
            except Exception:
                continue

    return class_counts, total_annotations

# %%
train_class_counts, train_total = analyze_class_distribution(TRAIN_LABELS_PATH)
valid_class_counts, valid_total = analyze_class_distribution(VALID_LABELS_PATH)

print(f"Training set: {train_total} total annotations")
print(f"Validation set: {valid_total} total annotations")
# Out:
# Analyzing labels:   0%|          | 0/1237 [00:00<?, ?it/s]
# Analyzing labels:   0%|          | 0/83 [00:00<?, ?it/s]
# Training set: 12032 total annotations
# Validation set: 872 total annotations

# %%
EPOCHS = 30
IMAGE_SIZE = 512
BATCH_SIZE = 4 if torch.cuda.is_available() else 2
PATIENCE = 5

model = YOLO('yolov8s-seg.pt')

results = model.train(
    data=CUSTOM_YAML_PATH,
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH_SIZE,
    patience=PATIENCE,
    save=True,
    save_period=10,
    project=OUTPUT_DIR,
    name='alphadent_yolov8s',
    exist_ok=True,
    pretrained=True,
    optimizer='AdamW',
    lr0=0.001,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=3.0,
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,
    box=7.5,
    cls=0.5,
    dfl=1.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=0.0,
    translate=0.1,
    scale=0.5,
    shear=0.0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.5,
    mosaic=1.0,
    mixup=0.0,
    copy_paste=0.0,
    plots=True,
    device=0 if torch.cuda.is_available() else 'cpu',
    workers=2,
    verbose=True,
    amp=True,
    val=True
)
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content//alphadent_config.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=512, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=alphadent_yolov8s, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/alphadent_yolov8s, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2774027  ultralytics.nn.modules.head.Segment          [9, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 151 layers, 11,793,579 parameters, 11,793,563 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2649.0±1554.7 MB/s, size: 3287.1 KB)
# train: Scanning /content/alpha_dent_data/AlphaDent/labels/train.cache... 1237 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1237/1237 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2095.7±1685.0 MB/s, size: 3172.8 KB)
# val: Scanning /content/alpha_dent_data/AlphaDent/labels/valid.cache... 83 images, 0 backgrounds, 0 corrupt: 100%|██████████| 83/83 [00:00<?, ?it/s]
# Plotting labels to /content/alphadent_yolov8s/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 2 dataloader workers
# Logging results to /content/alphadent_yolov8s
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      1.17G      1.055      2.596      1.746      1.019         18        512: 100%|██████████| 310/310 [02:59<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.46it/s]
#                    all         83        872      0.257      0.224      0.148     0.0944      0.218      0.188      0.123     0.0735
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      1.29G       1.01      2.345      1.441     0.9883          5        512: 100%|██████████| 310/310 [03:00<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
#                    all         83        872      0.271      0.248      0.195      0.113      0.236      0.226      0.174     0.0961
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      1.33G     0.9986      2.285      1.399     0.9796         23        512: 100%|██████████| 310/310 [02:57<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
#                    all         83        872      0.431      0.246      0.205      0.121      0.409      0.234      0.189     0.0977
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      1.33G     0.9934      2.266      1.342     0.9766         15        512: 100%|██████████| 310/310 [02:57<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
#                    all         83        872      0.449      0.261       0.22      0.132      0.411      0.245      0.202      0.108
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      1.33G     0.9568      2.173      1.283     0.9669         37        512: 100%|██████████| 310/310 [02:59<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
#                    all         83        872      0.585      0.299      0.242      0.142      0.568      0.277      0.218      0.119
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      1.33G     0.9411      2.148      1.275     0.9601          7        512: 100%|██████████| 310/310 [02:59<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.50it/s]
#                    all         83        872      0.473      0.301      0.253       0.15      0.459      0.279      0.231      0.124
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      1.33G     0.9402      2.094      1.255     0.9643         13        512: 100%|██████████| 310/310 [02:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
#                    all         83        872      0.499      0.287      0.259      0.155      0.455      0.318      0.236      0.123
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      1.33G     0.9107      2.052      1.201     0.9506          8        512: 100%|██████████| 310/310 [02:59<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.55it/s]
#                    all         83        872       0.47      0.265      0.266      0.161      0.465       0.26      0.252      0.134
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      1.33G     0.9027      1.989      1.158     0.9484         24        512: 100%|██████████| 310/310 [02:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
#                    all         83        872      0.487      0.321      0.282      0.171      0.482      0.315      0.262      0.144
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/30      1.33G      0.904      2.002      1.152     0.9482          8        512: 100%|██████████| 310/310 [03:01<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.52it/s]
#                    all         83        872      0.516      0.348      0.304      0.186      0.507      0.329      0.294      0.161
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/30      1.33G     0.8789      1.937      1.134     0.9388         42        512: 100%|██████████| 310/310 [02:59<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
#                    all         83        872      0.524      0.317      0.297      0.187      0.515      0.302      0.277      0.158
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/30      1.37G     0.9026      1.952       1.14     0.9489         35        512: 100%|██████████| 310/310 [02:59<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
#                    all         83        872      0.378      0.357       0.29      0.179      0.364      0.335      0.269      0.149
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/30      1.41G     0.8861      1.921      1.113     0.9406         21        512: 100%|██████████| 310/310 [02:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.54it/s]
#                    all         83        872      0.537      0.345      0.338      0.206       0.53      0.338      0.321      0.176
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/30      1.41G     0.8767      1.923      1.092     0.9399         47        512: 100%|██████████| 310/310 [02:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
#                    all         83        872      0.505      0.354      0.321      0.197      0.501      0.341      0.311      0.166
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/30      1.41G     0.8657      1.873      1.052     0.9297         10        512: 100%|██████████| 310/310 [02:59<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.56it/s]
#                    all         83        872      0.527      0.358       0.34      0.208      0.531      0.339       0.33      0.182
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/30      1.44G     0.8606      1.863      1.073     0.9318         22        512: 100%|██████████| 310/310 [02:58<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
#                    all         83        872      0.494      0.368      0.331      0.206      0.468      0.349      0.307      0.177
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/30      1.48G     0.8488       1.85      1.056     0.9291         16        512: 100%|██████████| 310/310 [02:57<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.46it/s]
#                    all         83        872      0.523       0.35      0.331      0.205      0.518       0.33      0.316      0.176
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/30      1.48G     0.8483      1.814      1.048     0.9297         20        512: 100%|██████████| 310/310 [03:00<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
#                    all         83        872       0.39      0.373      0.341      0.212       0.44      0.332      0.322      0.184
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/30      1.48G     0.8557      1.842      1.037     0.9329         24        512: 100%|██████████| 310/310 [02:59<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.54it/s]
#                    all         83        872      0.529      0.378      0.348      0.215      0.518       0.34      0.329      0.184
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/30      1.48G     0.8298      1.785     0.9879      0.923          8        512: 100%|██████████| 310/310 [02:59<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
#                    all         83        872      0.544      0.383      0.358       0.22      0.535      0.368      0.344      0.192
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/30      1.48G     0.8302      1.808      1.016     0.9311          8        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.43it/s]
#                    all         83        872      0.491      0.362      0.329      0.208      0.485      0.345       0.31      0.177
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/30      1.48G     0.8061      1.761     0.9741       0.92         13        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
#                    all         83        872      0.518      0.337      0.344      0.217      0.506      0.328      0.328      0.185
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/30      1.48G     0.8084       1.77      0.959     0.9214         14        512: 100%|██████████| 310/310 [02:43<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.54it/s]
#                    all         83        872      0.503      0.366      0.344      0.219      0.504      0.352      0.336      0.189
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/30      1.48G     0.8055      1.723     0.9332     0.9192          3        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.50it/s]
#                    all         83        872       0.43       0.36      0.359       0.22       0.56      0.343      0.351      0.189
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       25/30      1.48G     0.7969      1.693     0.9148      0.914          8        512: 100%|██████████| 310/310 [02:40<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:06<00:00,  1.61it/s]
#                    all         83        872      0.575      0.347      0.365      0.232      0.567       0.34      0.351      0.198
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      1.48G     0.7953      1.694     0.8972     0.9156         11        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
#                    all         83        872      0.551      0.366      0.364      0.226      0.545      0.358      0.351      0.198
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      1.48G     0.7818      1.665     0.8802     0.9122          6        512: 100%|██████████| 310/310 [02:40<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.44it/s]
#                    all         83        872      0.566      0.362      0.373       0.23      0.567       0.36      0.361      0.195
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      1.48G     0.7694      1.654     0.8752     0.9095          5        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
#                    all         83        872      0.446      0.366      0.371      0.231      0.449       0.35      0.353      0.198
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      1.48G     0.7757      1.629      0.882     0.9064          8        512: 100%|██████████| 310/310 [02:41<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
#                    all         83        872      0.463      0.345      0.369      0.229      0.465      0.342      0.353      0.196
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      1.48G       0.76      1.619     0.8395     0.9063          6        512: 100%|██████████| 310/310 [02:43<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:07<00:00,  1.41it/s]
#                    all         83        872      0.438      0.354      0.367      0.231      0.438      0.351      0.354      0.196
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 25, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 30 epochs completed in 1.520 hours.
# Optimizer stripped from /content/alphadent_yolov8s/weights/last.pt, 23.8MB
# Optimizer stripped from /content/alphadent_yolov8s/weights/best.pt, 23.8MB
#
# Validating /content/alphadent_yolov8s/weights/best.pt...
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,783,083 parameters, 0 gradients, 42.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/11 [00:00<?, ?it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   9%|▉         | 1/11 [00:00<00:01,  5.88it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):  18%|█▊        | 2/11 [00:00<00:03,  2.93it/s]
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
# WARNING ⚠️ Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:09<00:00,  1.14it/s]
#                    all         83        872      0.577      0.342      0.364      0.232      0.567       0.34      0.351      0.198
#               Abrasion         73        409      0.615      0.893      0.836      0.744      0.614      0.895      0.833      0.647
#                Filling         48        186      0.639      0.613      0.608       0.32      0.619      0.602      0.594      0.273
#                  Crown          9         19      0.414      0.632      0.702      0.578      0.417       0.64      0.702      0.513
#         Caries Class 1         30         62      0.382      0.339      0.335      0.138      0.346      0.323      0.267     0.0926
#         Caries Class 2         41         73       0.52      0.151      0.266     0.0936      0.513      0.151       0.25     0.0679
#         Caries Class 3         23         33      0.103     0.0303     0.0815     0.0176     0.0878     0.0303     0.0728     0.0157
#         Caries Class 4          3          4          1          0    0.00423    0.00127          1          0          0          0
#         Caries Class 5         21         81      0.517      0.424      0.407      0.178      0.505      0.416      0.409      0.164
#         Caries Class 6          4          5          1          0      0.039     0.0182          1          0     0.0347     0.0129
# Speed: 0.2ms preprocess, 4.6ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to /content/alphadent_yolov8s

# %%
best_model_path = f'{OUTPUT_DIR}/alphadent_yolov8s/weights/best.pt'

# %%
try:
    metrics = model.val(
        data=CUSTOM_YAML_PATH,
        imgsz=IMAGE_SIZE,
        batch=1,
        conf=0.001,
        iou=0.5,
        max_det=300,
        device=0 if torch.cuda.is_available() else 'cpu',
        plots=False,
        save_json=False,
    )

    print(f"\nValidation Results:")
    print(f"mAP@50: {metrics.seg.map50:.4f}")
    print(f"mAP@50-95: {metrics.seg.map:.4f}")
except Exception as e:
    print(f"Validation error (non-critical): {e}")
# Out:
# Ultralytics 8.3.179 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s-seg summary (fused): 85 layers, 11,783,083 parameters, 0 gradients, 42.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3673.7±462.5 MB/s, size: 3129.0 KB)
# val: Scanning /content/alpha_dent_data/AlphaDent/labels/valid.cache... 83 images, 0 backgrounds, 0 corrupt: 100%|██████████| 83/83 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 83/83 [00:11<00:00,  6.99it/s]
#                    all         83        872      0.548      0.368      0.374      0.231      0.562       0.36      0.362      0.197
#               Abrasion         73        409      0.573      0.916      0.836      0.747      0.582       0.91      0.834      0.644
#                Filling         48        186      0.628      0.608      0.617      0.314      0.656      0.602      0.609      0.264
#                  Crown          9         19      0.393      0.684      0.701      0.566      0.408      0.684      0.701      0.501
#         Caries Class 1         30         62      0.366      0.387      0.375      0.148      0.397      0.351      0.282     0.0979
#         Caries Class 2         41         73      0.346      0.192      0.285      0.096      0.379      0.184      0.269     0.0686
#         Caries Class 3         23         33      0.189     0.0909     0.0879     0.0114      0.134     0.0606     0.0826      0.016
#         Caries Class 4          3          4          1          0    0.00506    0.00152          1          0          0          0
#         Caries Class 5         21         81       0.44      0.432      0.414      0.175        0.5      0.444      0.435      0.167
#         Caries Class 6          4          5          1          0     0.0415     0.0178          1          0     0.0415     0.0154
# Speed: 0.4ms preprocess, 29.4ms inference, 0.0ms loss, 6.3ms postprocess per image
# Validation Results:
# mAP@50: 0.3616
# mAP@50-95: 0.1970

# %%
def convert_to_submission_format(results, image_paths):
    submission_rows = []

    for idx, result in enumerate(results):
        # image ID
        image_id = os.path.basename(image_paths[idx]).replace('.jpg', '')

        if result.masks is not None and len(result.masks) > 0:
            try:
                # Get masks, classes, and confidences
                masks = result.masks.xy
                classes = result.boxes.cls.cpu().numpy().astype(int)
                confidences = result.boxes.conf.cpu().numpy()
                h, w = result.orig_shape

                # Process each detection
                for mask_idx in range(len(masks)):
                    if mask_idx < len(classes) and mask_idx < len(confidences):
                        polygon = masks[mask_idx]

                        if len(polygon) >= 3:  # Valid polygon (at least 3 points)
                            # Normalize coordinates to [0, 1]
                            normalized_coords = []
                            for point in polygon:
                                x_norm = float(point[0]) / w
                                y_norm = float(point[1]) / h
                                # Ensure coordinates are within [0, 1]
                                x_norm = max(0.0, min(1.0, x_norm))
                                y_norm = max(0.0, min(1.0, y_norm))
                                normalized_coords.extend([x_norm, y_norm])

                            # Format polygon string
                            poly_str = ' '.join([f'{coord:.6f}' for coord in normalized_coords])

                            submission_rows.append({
                                'patient_id': image_id,
                                'class_id': int(classes[mask_idx]),
                                'confidence': float(confidences[mask_idx]),
                                'poly': poly_str
                            })
            except Exception as e:
                print(f"Error processing result for image {idx}: {e}")
                continue

    return submission_rows

# %%
test_images = sorted(glob.glob(f'{TEST_IMAGES_PATH}/*.jpg'))
all_submission_rows = []
INFERENCE_BATCH_SIZE = 4 if torch.cuda.is_available() else 2

# %%
for i in tqdm(range(0, len(test_images), INFERENCE_BATCH_SIZE)):
    batch_images = test_images[i:i + INFERENCE_BATCH_SIZE]

    try:
        results = model.predict(
            batch_images,
            imgsz=IMAGE_SIZE,
            conf=0.25,  # Confidence threshold
            iou=0.45,   # NMS IoU threshold
            max_det=300,
            device=0 if torch.cuda.is_available() else 'cpu',
            verbose=False,
            agnostic_nms=True,
            retina_masks=True,
        )

        # Convert results to submission format
        batch_rows = convert_to_submission_format(results, batch_images)
        all_submission_rows.extend(batch_rows)

    except Exception as e:
        print(f"Error in batch {i//INFERENCE_BATCH_SIZE}: {e}")
        continue

print(f"\nGenerated {len(all_submission_rows)} predictions")
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# Generated 1414 predictions

# %%
submission_df = pd.DataFrame(all_submission_rows)

# %%
all_test_ids = [os.path.basename(img).replace('.jpg', '') for img in test_images]
if len(submission_df) > 0:
    predicted_ids = submission_df['patient_id'].unique()
    missing_ids = set(all_test_ids) - set(predicted_ids)
else:
    missing_ids = set(all_test_ids)

# Add dummy predictions for images without detections
if missing_ids:
    print(f"Adding dummy predictions for {len(missing_ids)} images without detections")
    dummy_rows = []
    for img_id in missing_ids:
        # Create a small dummy polygon
        dummy_rows.append({
            'patient_id': img_id,
            'class_id': 0,
            'confidence': 0.01,
            'poly': '0.1 0.1 0.1 0.2 0.2 0.2 0.2 0.1'
        })

    submission_df = pd.concat([submission_df, pd.DataFrame(dummy_rows)], ignore_index=True)
# Out:
# Adding dummy predictions for 1 images without detections

# %%
submission_df = submission_df.sort_values(['patient_id', 'confidence'], ascending=[True, False])

# correct column order
submission_df = submission_df[['patient_id', 'class_id', 'confidence', 'poly']]

submission_df.to_csv('submission.csv', index=False)

# %%
submission_df.head()
# Out:
#   patient_id  class_id  confidence  \
# 0   test_000         7    0.785457
# 1   test_000         0    0.753609
# 2   test_000         7    0.665054
# 3   test_000         7    0.636561
# 4   test_000         7    0.574530
#
#                                                 poly
# 0  0.231250 0.644792 0.230729 0.645573 0.230556 0...
# 1  0.436458 0.350521 0.436458 0.350781 0.436111 0...
# 2  0.353993 0.642448 0.353993 0.669792 0.356597 0...
# 3  0.739236 0.632292 0.739236 0.646094 0.739583 0...
# 4  0.590972 0.604688 0.590972 0.621875 0.591146 0...

# %%
missing_in_submission = set(all_test_ids) - set(submission_df['patient_id'].unique())
if missing_in_submission:
    print(f"Missing images in submission: {missing_in_submission}")
else:
    print("test images have predictions")
# Out:
# test images have predictions

# %%
print("\nPredictions per class:")
class_dist = submission_df['class_id'].value_counts().sort_index()
for class_id, count in class_dist.items():
    if 0 <= class_id < 9:
        print(f"  Class {class_id} ({CLASS_INFO[class_id]['name']}): {count}")
# Out:
# Predictions per class:
#   Class 0 (Abrasion): 797
#   Class 1 (Filling): 264
#   Class 2 (Crown): 70
#   Class 3 (Caries Class 1): 51
#   Class 4 (Caries Class 2): 53
#   Class 5 (Caries Class 3): 21
#   Class 7 (Caries Class 5): 159

# %%
high_conf_df = submission_df[submission_df['confidence'] >= 0.3].copy()

high_conf_ids = high_conf_df['patient_id'].unique()
missing_high_conf = set(all_test_ids) - set(high_conf_ids)

if missing_high_conf:
    for img_id in missing_high_conf:
        img_preds = submission_df[submission_df['patient_id'] == img_id]
        if len(img_preds) > 0:
            high_conf_df = pd.concat([high_conf_df, img_preds.head(1)], ignore_index=True)
        else:
            dummy_row = pd.DataFrame([{
                'patient_id': img_id,
                'class_id': 0,
                'confidence': 0.01,
                'poly': '0.1 0.1 0.1 0.2 0.2 0.2 0.2 0.1'
            }])
            high_conf_df = pd.concat([high_conf_df, dummy_row], ignore_index=True)

high_conf_df = high_conf_df.sort_values(['patient_id', 'confidence'], ascending=[True, False])
high_conf_df.to_csv('submission_high_conf.csv', index=False)
print(f"Created high confidence submission with {len(high_conf_df)} predictions")
# Out:
# Created high confidence submission with 1240 predictions
