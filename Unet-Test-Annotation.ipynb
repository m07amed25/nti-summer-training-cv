# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.179-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.15-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.179-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.15-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.179 ultralytics-thop-2.0.15

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.8.3)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c alpha-dent
# Out:
# Downloading alpha-dent.zip to /content
# 100% 4.54G/4.56G [00:40<00:00, 184MB/s]
# 100% 4.56G/4.56G [00:40<00:00, 120MB/s]

# %%
# !unzip alpha-dent.zip -d ./alpha_dent_dat
# Out:
# Archive:  alpha-dent.zip
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_000.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_009.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_010.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_011.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_012.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_013.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_014.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_015.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_016.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_017.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_018.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_019.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_020.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_021.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_022.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_023.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_024.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_025.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_026.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_027.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_028.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_029.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_030.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_031.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_032.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_033.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_034.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_035.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_036.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_037.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_038.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_039.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_040.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_041.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_042.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_043.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_044.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_045.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_046.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_047.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_048.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_049.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_050.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_051.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_052.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_053.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_054.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_055.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_056.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_057.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_058.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_059.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_060.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_061.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_062.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_063.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_064.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_065.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_066.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_067.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_068.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_069.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_070.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_071.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_072.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_073.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_074.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_075.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_076.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_077.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_078.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_079.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_080.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_081.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_082.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_083.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_084.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_085.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_086.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_087.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_088.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_089.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_090.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_091.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_092.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_093.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_094.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_095.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_096.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_097.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_098.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_099.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_100.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_101.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_102.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_103.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_104.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_105.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_106.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_107.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_108.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_109.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_110.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_111.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_112.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_113.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_114.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_115.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_116.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_117.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_118.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_119.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_120.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_121.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_122.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_123.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_124.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_125.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_126.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_127.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_128.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_129.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_130.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_131.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_132.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_133.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/test/test_134.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p002_F_52_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p002_F_52_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p002_F_52_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p002_F_52_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p002_F_52_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p003_M_27_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p003_M_27_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p004_M_34_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p004_M_34_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p004_M_34_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p005_M_51_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p005_M_51_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p005_M_51_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p006_F_15_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p006_F_15_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p006_F_15_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p007_M_51_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p007_M_51_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p007_M_51_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p008_M_26_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p008_M_26_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p008_M_26_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p009_M_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p009_M_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p009_M_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p010_M_34_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p010_M_34_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p010_M_34_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p010_M_34_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p010_M_34_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p011_M_59_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p011_M_59_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p011_M_59_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p012_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p012_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p012_F_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p013_M_37_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p013_M_37_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p013_M_37_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p014_F_46_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p014_F_46_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p014_F_46_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p014_F_46_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p016_M_37_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p016_M_37_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p016_M_37_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p017_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p017_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p017_F_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p018_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p018_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p018_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p019_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p019_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p019_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p020_F_42_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p020_F_42_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p020_F_42_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p020_F_42_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p021_M_49_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p022_F_28_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p022_F_28_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p022_F_28_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p023_F_22_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p023_F_22_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p023_F_22_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p024_F_52_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p024_F_52_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p024_F_52_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p025_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p025_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p027_M_50_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p027_M_50_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p027_M_50_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p027_M_50_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p028_F_44_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p028_F_44_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p028_F_44_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p029_F_30_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p029_F_30_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p030_M_31_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p030_M_31_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p030_M_31_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p031_M_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p031_M_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p032_F_38_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p032_F_38_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p032_F_38_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p033_M_61_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p033_M_61_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p033_M_61_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p033_M_61_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p033_M_61_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p035_F_28_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p035_F_28_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p035_F_28_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p037_M_49_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p037_M_49_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p037_M_49_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p038_F_35_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p038_F_35_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p038_F_35_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p039_M_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p039_M_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p039_M_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p040_M_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p040_M_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p040_M_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p041_F_48_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p041_F_48_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p041_F_48_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p042_F_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p042_F_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p042_F_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p043_F_24_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p043_F_24_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p043_F_24_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p045_M_10_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p045_M_10_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p046_M_25_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p046_M_25_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p046_M_25_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p047_M_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p047_M_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p047_M_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p048_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p048_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p048_F_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p049_M_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p049_M_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p049_M_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p050_M_44_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p050_M_44_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p050_M_44_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p051_M_21_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p051_M_21_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p051_M_21_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p052_M_11_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p052_M_11_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p052_M_11_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p053_M_08_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p054_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p054_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p054_F_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p055_F_23_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p055_F_23_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p055_F_23_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p057_M_37_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p057_M_37_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p057_M_37_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p058_M_53_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p058_M_53_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p058_M_53_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p059_M_13_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p059_M_13_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p059_M_13_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p060_M_29_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p060_M_29_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p060_M_29_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p061_M_18_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p061_M_18_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p061_M_18_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p062_M_35_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p062_M_35_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p062_M_35_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p063_F_51_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p063_F_51_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p063_F_51_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p064_F_62_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p064_F_62_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p064_F_62_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p065_F_51_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p065_F_51_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p065_F_51_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p067_M_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p067_M_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p067_M_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p068_F_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p068_F_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p068_F_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p070_M_38_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p070_M_38_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p070_M_38_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p071_M_44_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p071_M_44_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p071_M_44_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p072_F_26_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p072_F_26_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p072_F_26_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p073_F_38_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p073_F_38_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p073_F_38_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p074_M_27_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p074_M_27_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p074_M_27_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p075_F_28_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p075_F_28_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p075_F_28_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p076_F_13_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p076_F_13_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p076_F_13_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p077_F_43_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p077_F_43_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p077_F_43_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p079_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p079_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p079_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p080_F_45_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p080_F_45_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p080_F_45_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p081_F_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p081_F_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p081_F_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p082_M_39_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p082_M_39_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p082_M_39_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p083_F_26_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p083_F_26_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p083_F_26_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p084_M_36_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p084_M_36_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p084_M_36_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p085_F_41_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p085_F_41_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p085_F_41_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p086_F_26_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p086_F_26_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p086_F_26_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p087_F_42_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p087_F_42_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p087_F_42_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p088_M_29_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p088_M_29_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p088_M_29_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p089_F_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p089_F_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p089_F_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p090_F_47_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p090_F_47_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p090_F_47_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p091_F_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p091_F_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p091_F_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p092_F_43_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p092_F_43_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p092_F_43_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p093_F_18_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p093_F_18_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p093_F_18_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p094_F_30_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p094_F_30_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p094_F_30_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p095_M_30_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p095_M_30_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p095_M_30_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p096_F_58_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p096_F_58_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p096_F_58_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p098_M_60_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p098_M_60_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p098_M_60_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p099_F_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p099_F_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p099_F_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p100_F_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p100_F_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p100_F_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p102_F_47_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p102_F_47_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p102_F_47_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p103_M_25_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p103_M_25_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p103_M_25_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p104_M_21_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p104_M_21_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p104_M_21_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p105_M_44_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p105_M_44_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p105_M_44_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p106_F_41_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p106_F_41_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p106_F_41_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p107_M_41_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p107_M_41_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p107_M_41_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p108_M_41_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p108_M_41_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p108_M_41_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p109_F_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p109_F_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p109_F_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p110_F_35_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p110_F_35_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p110_F_35_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p111_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p111_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p111_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p112_F_24_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p112_F_24_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p112_F_24_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p112_F_24_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p113_F_41_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p114_M_32_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p115_F_31_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p116_M_33_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p117_M_44_009.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_009.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p118_F_45_010.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p119_F_31_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p119_F_31_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p119_F_31_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p119_F_31_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p120_F_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p120_F_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p120_F_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p121_M_32_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p122_F_34_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p122_F_34_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p122_F_34_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p122_F_34_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p123_F_30_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p123_F_30_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p124_M_29_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p125_M_34_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p126_M_33_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p127_F_46_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p127_F_46_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p127_F_46_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p127_F_46_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p128_F_47_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p128_F_47_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p128_F_47_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p128_F_47_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p128_F_47_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p129_M_35_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p129_M_35_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p129_M_35_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p129_M_35_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p129_M_35_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p130_M_48_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p130_M_48_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p131_F_31_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_009.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_010.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_011.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_012.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p132_M_25_013.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p133_M_34_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p134_M_54_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p134_M_54_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p134_M_54_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p135_F_37_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p136_F_54_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p136_F_54_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p136_F_54_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p137_M_37_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p137_M_37_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p137_M_37_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p137_M_37_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p138_M_20_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p139_M_45_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p139_M_45_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p140_F_38_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p140_F_38_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p140_F_38_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p140_F_38_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p140_F_38_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p141_M_33_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p142_F_29_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p142_F_29_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p142_F_29_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p142_F_29_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p142_F_29_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p143_F_29_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p143_F_29_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p143_F_29_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p144_F_27_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p145_M_53_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p145_M_53_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p146_M_39_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p146_M_39_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p147_F_28_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p147_F_28_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p147_F_28_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p148_F_31_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p148_F_31_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p148_F_31_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p148_F_31_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p149_M_14_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p149_M_14_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p149_M_14_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p149_M_14_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p149_M_14_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p150_F_40_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p151_F_18_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p151_F_18_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p151_F_18_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p151_F_18_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_006.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_007.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_008.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p152_M_28_009.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p153_F_42_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p153_F_42_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p153_F_42_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p153_F_42_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p153_F_42_005.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p154_F_36_001.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p154_F_36_002.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p154_F_36_003.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p154_F_36_004.jpg
#   inflating: ./alpha_dent_dat/AlphaDent/images/train/p154_F_36_005.jpg
# ...
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p264_F_27_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p264_F_27_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p264_F_27_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p264_F_27_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_009.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p265_F_48_010.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p267_M_28_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p268_M_30_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p268_M_30_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p268_M_30_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p268_M_30_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p268_M_30_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p269_F_62_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p270_F_30_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p271_M_32_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p272_M_32_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p272_M_32_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p273_F_30_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p273_F_30_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p273_F_30_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p273_F_30_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p274_F_50_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p276_F_28_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p276_F_28_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p276_F_28_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p277_F_34_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p277_F_34_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p277_F_34_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p277_F_34_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p277_F_34_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p278_F_18_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p278_F_18_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p278_F_18_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p279_M_28_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p279_M_28_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p279_M_28_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p279_M_28_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p280_M_40_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p280_M_40_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p280_M_40_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p280_M_40_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p281_F_27_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_009.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_010.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_011.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p282_F_38_012.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p284_F_37_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p284_F_37_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p286_M_40_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p287_F_20_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p288_F_36_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p288_F_36_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p289_F_36_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p289_F_36_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p289_F_36_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p289_F_36_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p290_M_38_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p290_M_38_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p290_M_38_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p290_M_38_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p290_M_38_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p291_F_28_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p292_F_36_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p292_F_36_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/train/p293_F_35_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p001_F_51_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p001_F_51_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p001_F_51_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p001_F_51_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p015_M_53_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p015_M_53_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p015_M_53_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p015_M_53_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p026_F_34_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p026_F_34_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p026_F_34_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p034_F_17_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p034_F_17_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p034_F_17_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p036_M_13_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p036_M_13_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p036_M_13_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p036_M_13_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p044_F_35_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p044_F_35_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p044_F_35_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p056_F_60_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p056_F_60_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p056_F_60_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p066_M_34_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p066_M_34_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p066_M_34_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p069_M_11_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p069_M_11_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p069_M_11_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p078_F_38_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p078_F_38_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p078_F_38_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p097_F_43_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p097_F_43_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p097_F_43_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p101_F_24_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p101_F_24_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p101_F_24_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p179_M_52_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p179_M_52_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p220_F_28_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p220_F_28_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p220_F_28_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p235_F_27_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p235_F_27_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p241_F_24_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p241_F_24_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p241_F_24_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p255_M_38_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p255_M_38_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p255_M_38_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_007.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_008.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_009.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_010.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_011.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p261_F_31_012.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p266_M_32_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p266_M_32_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p266_M_32_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p266_M_32_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p266_M_32_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p275_M_27_006.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p283_M_26_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p283_M_26_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p283_M_26_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p283_M_26_004.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p283_M_26_005.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p285_F_19_001.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p285_F_19_002.txt
#   inflating: ./alpha_dent_dat/AlphaDent/labels/valid/p285_F_19_003.txt
#   inflating: ./alpha_dent_dat/AlphaDent/yolo_seg_train.yaml
#   inflating: ./alpha_dent_dat/sample_submission.csv

# %%
# !pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.34.4)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (1.0.19)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.1.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.8.3)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: segmentation_models_pytorch
# Successfully installed segmentation_models_pytorch-0.5.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.transforms import functional as F
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import os
import json
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import albumentations as A
from albumentations.pytorch import ToTensorV2
import segmentation_models_pytorch as smp

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class ImprovedUNet(nn.Module):
    def __init__(self, in_channels=1, num_classes=1):
        super(ImprovedUNet, self).__init__()

        # Encoder
        self.enc1_1 = self._conv_block(in_channels, 64)
        self.enc1_2 = self._conv_block(64, 64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.enc2_1 = self._conv_block(64, 128)
        self.enc2_2 = self._conv_block(128, 128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.enc3_1 = self._conv_block(128, 256)
        self.enc3_2 = self._conv_block(256, 256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.enc4_1 = self._conv_block(256, 512)
        self.enc4_2 = self._conv_block(512, 512)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Bottleneck
        self.bottleneck1 = self._conv_block(512, 1024)
        self.bottleneck2 = self._conv_block(1024, 1024)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec1_1 = self._conv_block(1024, 512)
        self.dec1_2 = self._conv_block(512, 512)

        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec2_1 = self._conv_block(512, 256)
        self.dec2_2 = self._conv_block(256, 256)

        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec3_1 = self._conv_block(256, 128)
        self.dec3_2 = self._conv_block(128, 128)

        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec4_1 = self._conv_block(128, 64)
        self.dec4_2 = self._conv_block(64, 64)

        self.final_conv = nn.Conv2d(64, num_classes, kernel_size=1)

        # Initialize weights
        self._initialize_weights()

    def _conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        # Encoder
        enc1 = self.enc1_2(self.enc1_1(x))
        pool1 = self.pool1(enc1)

        enc2 = self.enc2_2(self.enc2_1(pool1))
        pool2 = self.pool2(enc2)

        enc3 = self.enc3_2(self.enc3_1(pool2))
        pool3 = self.pool3(enc3)

        enc4 = self.enc4_2(self.enc4_1(pool3))
        pool4 = self.pool4(enc4)

        # Bottleneck
        bottleneck = self.bottleneck2(self.bottleneck1(pool4))

        # Decoder with skip connections
        up1 = self.upconv1(bottleneck)
        merge1 = torch.cat([up1, enc4], dim=1)
        dec1 = self.dec1_2(self.dec1_1(merge1))

        up2 = self.upconv2(dec1)
        merge2 = torch.cat([up2, enc3], dim=1)
        dec2 = self.dec2_2(self.dec2_1(merge2))

        up3 = self.upconv3(dec2)
        merge3 = torch.cat([up3, enc2], dim=1)
        dec3 = self.dec3_2(self.dec3_1(merge3))

        up4 = self.upconv4(dec3)
        merge4 = torch.cat([up4, enc1], dim=1)
        dec4 = self.dec4_2(self.dec4_1(merge4))

        # Final output
        output = self.final_conv(dec4)
        return torch.sigmoid(output)

# %%
def parse_txt_annotation(txt_path, img_shape, annotation_format='yolo'):
    mask = np.zeros(img_shape, dtype=np.uint8)

    if not os.path.exists(txt_path):
        return mask

    with open(txt_path, 'r') as f:
        lines = f.readlines()

    height, width = img_shape

    for line in lines:
        line = line.strip()
        if not line:
            continue

        parts = line.split()

        if annotation_format == 'yolo':
            # YOLO
            if len(parts) >= 5:
                class_id, center_x, center_y, w, h = map(float, parts[:5])

                center_x *= width
                center_y *= height
                w *= width
                h *= height

                x1 = int(center_x - w/2)
                y1 = int(center_y - h/2)
                x2 = int(center_x + w/2)
                y2 = int(center_y + h/2)

                x1 = max(0, min(x1, width-1))
                y1 = max(0, min(y1, height-1))
                x2 = max(0, min(x2, width-1))
                y2 = max(0, min(y2, height-1))

                # Fill
                mask[y1:y2, x1:x2] = 255

        elif annotation_format == 'polygon':
            if len(parts) >= 7:
                class_id = int(parts[0])
                coords = list(map(float, parts[1:]))

                points = np.array(coords).reshape(-1, 2)

                # convert to pixels
                if np.all(points <= 1.0):
                    points[:, 0] *= width
                    points[:, 1] *= height

                points = points.astype(np.int32)

                # Fill polygon
                cv2.fillPoly(mask, [points], 255)

        elif annotation_format == 'coco':
            # COCO format
            if len(parts) >= 5:
                class_id, x, y, w, h = map(float, parts[:5])

                x1, y1 = int(x), int(y)
                x2, y2 = int(x + w), int(y + h)

                # Ensure coordinates are within image bounds
                x1 = max(0, min(x1, width-1))
                y1 = max(0, min(y1, height-1))
                x2 = max(0, min(x2, width-1))
                y2 = max(0, min(y2, height-1))

                mask[y1:y2, x1:x2] = 255

        elif annotation_format == 'points':
            # Points format
            coords = list(map(float, parts))
            if len(coords) >= 4 and len(coords) % 2 == 0:
                points = np.array(coords).reshape(-1, 2)

                if np.all(points <= 1.0):
                    points[:, 0] *= width
                    points[:, 1] *= height

                points = points.astype(np.int32)

                # Create contour and fill
                if len(points) >= 3:
                    cv2.fillPoly(mask, [points], 255)

    return mask

# %%
def detect_annotation_format(txt_path):
    if not os.path.exists(txt_path):
        return 'yolo'  # default

    with open(txt_path, 'r') as f:
        lines = f.readlines()

    if not lines:
        return 'yolo'

    for line in lines:
        line = line.strip()
        if line:
            parts = line.split()
            if len(parts) >= 5:
                # Try to determine format based on values
                coords = [float(x) for x in parts[1:5]]

                # If all coordinates are between 0 and 1, likely YOLO format
                if all(0 <= coord <= 1 for coord in coords):
                    return 'yolo'
                # If coordinates are larger, likely COCO or polygon format
                else:
                    return 'coco'
            elif len(parts) > 6:
                return 'polygon'
            break

    return 'yolo'  # default

# %%
class DentalDataset(Dataset):
    def __init__(self, images_dir, annotations_dir, image_list, transform=None, annotation_format='auto'):
        self.images_dir = images_dir
        self.annotations_dir = annotations_dir
        self.image_list = image_list
        self.transform = transform
        self.annotation_format = annotation_format

    def __len__(self):
        return len(self.image_list)

    def __getitem__(self, idx):
        img_name = self.image_list[idx]

        img_path = os.path.join(self.images_dir, img_name)
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if image is None:
            raise ValueError(f"Could not load image: {img_path}")

        base_name = os.path.splitext(img_name)[0]
        txt_name = base_name + '.txt'
        txt_path = os.path.join(self.annotations_dir, txt_name)

        if self.annotation_format == 'auto':
            format_type = detect_annotation_format(txt_path)
        else:
            format_type = self.annotation_format

        # text to mask
        mask = parse_txt_annotation(txt_path, image.shape, format_type)

        # Normalize
        image = image.astype(np.float32) / 255.0
        mask = mask.astype(np.float32) / 255.0

        if self.transform:
            transformed = self.transform(image=image, mask=mask)
            image = transformed['image']
            mask = transformed['mask']

        # Add channel dimension
        if len(image.shape) == 2:
            image = np.expand_dims(image, axis=0)
        if len(mask.shape) == 2:
            mask = np.expand_dims(mask, axis=0)

        return torch.FloatTensor(image), torch.FloatTensor(mask)

# %%
train_transform = A.Compose([
    A.Resize(512, 512),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=15, p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.3),
    A.GaussNoise(var_limit=(10.0, 50.0), p=0.3),
    A.OneOf([
        A.GridDistortion(p=1.0),
        A.OpticalDistortion(distort_limit=2, shift_limit=0.5, p=1.0),
    ], p=0.3),
])

val_transform = A.Compose([
    A.Resize(512, 512),
])
# Out:
# /tmp/ipython-input-1648065043.py:6: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.3),
# /tmp/ipython-input-1648065043.py:7: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0), p=0.3),
# /tmp/ipython-input-1648065043.py:10: UserWarning: Argument(s) 'shift_limit' are not valid for transform OpticalDistortion
#   A.OpticalDistortion(distort_limit=2, shift_limit=0.5, p=1.0),

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super(DiceLoss, self).__init__()
        self.smooth = smooth

    def forward(self, predictions, targets):
        predictions = predictions.flatten()
        targets = targets.flatten()

        intersection = (predictions * targets).sum()
        dice = (2. * intersection + self.smooth) / (predictions.sum() + targets.sum() + self.smooth)

        return 1 - dice

class CombinedLoss(nn.Module):
    def __init__(self, bce_weight=0.5, dice_weight=0.5):
        super(CombinedLoss, self).__init__()
        self.bce_weight = bce_weight
        self.dice_weight = dice_weight
        self.bce_loss = nn.BCELoss()
        self.dice_loss = DiceLoss()

    def forward(self, predictions, targets):
        bce = self.bce_loss(predictions, targets)
        dice = self.dice_loss(predictions, targets)
        return self.bce_weight * bce + self.dice_weight * dice

def dice_coefficient(pred, target, smooth=1e-6):
    pred = (pred > 0.5).float()
    target = target.float()

    intersection = (pred * target).sum(dim=(2, 3))
    union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3))

    dice = (2. * intersection + smooth) / (union + smooth)
    return dice.mean()

def iou_score(pred, target, smooth=1e-6):
    pred = (pred > 0.5).float()
    target = target.float()

    intersection = (pred * target).sum(dim=(2, 3))
    union = pred.sum(dim=(2, 3)) + target.sum(dim=(2, 3)) - intersection

    iou = (intersection + smooth) / (union + smooth)
    return iou.mean()

# %%
def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    total_dice = 0
    total_iou = 0

    pbar = tqdm(dataloader, desc='Training')
    for batch_idx, (images, masks) in enumerate(pbar):
        images, masks = images.to(device), masks.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, masks)

        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        total_dice += dice_coefficient(outputs, masks).item()
        total_iou += iou_score(outputs, masks).item()

        pbar.set_postfix({
            'Loss': f'{loss.item():.4f}',
            'Dice': f'{dice_coefficient(outputs, masks).item():.4f}',
            'IoU': f'{iou_score(outputs, masks).item():.4f}'
        })

    return total_loss / len(dataloader), total_dice / len(dataloader), total_iou / len(dataloader)

# %%
def validate_epoch(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0
    total_dice = 0
    total_iou = 0

    with torch.no_grad():
        pbar = tqdm(dataloader, desc='Validation')
        for images, masks in pbar:
            images, masks = images.to(device), masks.to(device)

            outputs = model(images)
            loss = criterion(outputs, masks)

            total_loss += loss.item()
            total_dice += dice_coefficient(outputs, masks).item()
            total_iou += iou_score(outputs, masks).item()

            pbar.set_postfix({
                'Loss': f'{loss.item():.4f}',
                'Dice': f'{dice_coefficient(outputs, masks).item():.4f}',
                'IoU': f'{iou_score(outputs, masks).item():.4f}'
            })

    return total_loss / len(dataloader), total_dice / len(dataloader), total_iou / len(dataloader)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs, device, save_path):
    best_val_dice = 0
    train_losses, val_losses = [], []
    train_dices, val_dices = [], []
    train_ious, val_ious = [], []

    for epoch in range(num_epochs):
        print(f'\nEpoch [{epoch+1}/{num_epochs}]')

        train_loss, train_dice, train_iou = train_epoch(model, train_loader, criterion, optimizer, device)

        val_loss, val_dice, val_iou = validate_epoch(model, val_loader, criterion, device)

        scheduler.step(val_loss)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_dices.append(train_dice)
        val_dices.append(val_dice)
        train_ious.append(train_iou)
        val_ious.append(val_iou)

        print(f'Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
        print(f'Train Dice: {train_dice:.4f}, Val Dice: {val_dice:.4f}')
        print(f'Train IoU: {train_iou:.4f}, Val IoU: {val_iou:.4f}')
        print(f'Learning Rate: {optimizer.param_groups[0]["lr"]:.6f}')

        # Save best model
        if val_dice > best_val_dice:
            best_val_dice = val_dice
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'best_val_dice': best_val_dice,
                'train_losses': train_losses,
                'val_losses': val_losses,
                'train_dices': train_dices,
                'val_dices': val_dices,
                'train_ious': train_ious,
                'val_ious': val_ious
            }, save_path)
            print(f'Model saved with validation Dice: {val_dice:.4f}')

    return train_losses, val_losses, train_dices, val_dices, train_ious, val_ious

# %%
def predict_single_image(model, image_path, device, transform=None):
    model.eval()

    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    original_size = image.shape

    image = image.astype(np.float32) / 255.0

    if transform:
        transformed = transform(image=image)
        image = transformed['image']

    if len(image.shape) == 2:
        image = np.expand_dims(image, axis=0)

    image = torch.FloatTensor(image).unsqueeze(0).to(device)

    with torch.no_grad():
        prediction = model(image)
        prediction = torch.sigmoid(prediction)
        prediction = prediction.squeeze().cpu().numpy()

    prediction = cv2.resize(prediction, (original_size[1], original_size[0]))

    return prediction

# %%
def visualize_annotation(image_path, txt_path, annotation_format='auto'):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    if image is None:
        print(f"Could not load image: {image_path}")
        return

    if annotation_format == 'auto':
        annotation_format = detect_annotation_format(txt_path)

    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    mask = parse_txt_annotation(txt_path, gray_image.shape, annotation_format)

    overlay = image.copy()
    overlay[mask > 0] = [0, 255, 0]  # Green overlay
    result = cv2.addWeighted(image, 0.7, overlay, 0.3, 0)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(mask, cmap='gray')
    plt.title(f'Generated Mask ({annotation_format} format)')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
    plt.title('Overlay')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
def test_annotation_parsing(images_dir, annotations_dir, num_samples=5):
    image_files = [f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    for i, img_name in enumerate(image_files[:num_samples]):
        print(f"\nTesting annotation for: {img_name}")

        img_path = os.path.join(images_dir, img_name)
        base_name = os.path.splitext(img_name)[0]
        txt_path = os.path.join(annotations_dir, base_name + '.txt')

        if not os.path.exists(txt_path):
            print(f"No annotation file found: {txt_path}")
            continue

        # Detect format
        detected_format = detect_annotation_format(txt_path)
        print(f"Detected annotation format: {detected_format}")

        with open(txt_path, 'r') as f:
            lines = f.readlines()[:3]
            print("Annotation content (first 3 lines):")
            for line in lines:
                print(f"  {line.strip()}")

        # Visualize
        visualize_annotation(img_path, txt_path)

# %%
def convert_txt_to_masks(images_dir, annotations_dir, masks_output_dir, annotation_format='auto'):
    os.makedirs(masks_output_dir, exist_ok=True)

    image_files = [f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    for img_name in tqdm(image_files, desc="Converting annotations to masks"):
        img_path = os.path.join(images_dir, img_name)
        base_name = os.path.splitext(img_name)[0]
        txt_path = os.path.join(annotations_dir, base_name + '.txt')

        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            continue

        if annotation_format == 'auto':
            format_type = detect_annotation_format(txt_path)
        else:
            format_type = annotation_format

        mask = parse_txt_annotation(txt_path, image.shape, format_type)

        mask_name = base_name + '.png'
        mask_path = os.path.join(masks_output_dir, mask_name)
        cv2.imwrite(mask_path, mask)

# %%
def visualize_results(image, mask, prediction, title="Segmentation Results"):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    axes[0].imshow(image, cmap='gray')
    axes[0].set_title('Original Image')
    axes[0].axis('off')

    axes[1].imshow(mask, cmap='gray')
    axes[1].set_title('Ground Truth')
    axes[1].axis('off')

    axes[2].imshow(prediction, cmap='gray')
    axes[2].set_title('Prediction')
    axes[2].axis('off')

    plt.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
def main():
    config = {
        'data_dir': '/content/alpha_dent_dat/AlphaDent',
        'images_dir': '/content/alpha_dent_dat/AlphaDent/images/train',
        'annotations_dir': '/content/alpha_dent_dat/AlphaDent/labels/train',
        'annotation_format': 'auto',
        'batch_size': 4,
        'learning_rate': 1e-4,
        'num_epochs': 10,
        'model_save_path': 'best_unet_model.pth',
        'convert_masks': False,
        'masks_output_dir': '/content/'
    }

    print("Testing annotation parsing...")
    test_annotation_parsing(config['images_dir'], config['annotations_dir'], num_samples=3)

    # if config['convert_masks']:
    #     print("Converting text annotations to mask images...")
    #     convert_txt_to_masks(
    #         config['images_dir'],
    #         config['annotations_dir'],
    #         config['masks_output_dir'],
    #         config['annotation_format']
    #     )

    # all_files = os.listdir(config['images_dir'])
    # print(f"All files in {config['images_dir']}: {all_files[:10]}...")

    # image_files = [f for f in all_files if f.endswith(('.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG'))]
    # print(f"Found {len(image_files)} images")


    # train_files, val_files = train_test_split(image_files, test_size=0.2, random_state=42)
    # print(f"Training on {len(train_files)} images, validating on {len(val_files)} images")

    # train_dataset = DentalDataset(
    #     config['images_dir'],
    #     config['annotations_dir'],
    #     train_files,
    #     transform=train_transform,
    #     annotation_format=config['annotation_format']
    # )
    # val_dataset = DentalDataset(
    #     config['images_dir'],
    #     config['annotations_dir'],
    #     val_files,
    #     transform=val_transform,
    #     annotation_format=config['annotation_format']
    # )

    # train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True, num_workers=4)
    # val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False, num_workers=4)

    # model = ImprovedUNet(in_channels=1, num_classes=1).to(device)

    # criterion = CombinedLoss(bce_weight=0.5, dice_weight=0.5)
    # optimizer = optim.AdamW(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, verbose=True)

    # print(f"Model has {sum(p.numel() for p in model.parameters() if p.requires_grad):,} trainable parameters")

    # train_losses, val_losses, train_dices, val_dices, train_ious, val_ious = train_model(
    #     model, train_loader, val_loader, criterion, optimizer, scheduler,
    #     config['num_epochs'], device, config['model_save_path']
    # )

    # plt.figure(figsize=(15, 5))

    # plt.subplot(1, 3, 1)
    # plt.plot(train_losses, label='Train Loss')
    # plt.plot(val_losses, label='Val Loss')
    # plt.title('Loss')
    # plt.xlabel('Epoch')
    # plt.ylabel('Loss')
    # plt.legend()

    # plt.subplot(1, 3, 2)
    # plt.plot(train_dices, label='Train Dice')
    # plt.plot(val_dices, label='Val Dice')
    # plt.title('Dice Coefficient')
    # plt.xlabel('Epoch')
    # plt.ylabel('Dice')
    # plt.legend()

    # plt.subplot(1, 3, 3)
    # plt.plot(train_ious, label='Train IoU')
    # plt.plot(val_ious, label='Val IoU')
    # plt.title('IoU Score')
    # plt.xlabel('Epoch')
    # plt.ylabel('IoU')
    # plt.legend()

    # plt.tight_layout()
    # plt.show()

    print("Training completed!")

# %%
if __name__ == "__main__":
    main()
# Out:
# Testing annotation parsing...
#
# Testing annotation for: p156_M_36_001.jpg
# Detected annotation format: yolo
# Annotation content (first 3 lines):
#   5 0.58168860 0.41474781 0.58059211 0.41639254 0.58040936 0.41639254 0.57931287 0.41803728 0.57913012 0.41803728 0.57803363 0.41968202 0.57785088 0.41968202 0.57657164 0.42160088 0.57638889 0.42160088 0.57529240 0.42324561 0.57510965 0.42324561 0.57401316 0.42489035 0.57383041 0.42489035 0.57255117 0.42680921 0.57236842 0.42680921 0.57127193 0.42845395 0.57108918 0.42845395 0.56999269 0.43009868 0.56980994 0.43009868 0.56853070 0.43201754 0.56834795 0.43201754 0.56761696 0.43311404 0.56761696 0.43366228 0.56779971 0.43393640 0.56779971 0.43585526 0.56798246 0.43612939 0.56798246 0.43832237 0.56816520 0.43859649 0.56816520 0.44078947 0.56834795 0.44106360 0.56834795 0.44325658 0.56853070 0.44353070 0.56853070 0.44544956 0.56871345 0.44572368 0.56871345 0.44791667 0.56889620 0.44819079 0.56889620 0.45038377 0.56907895 0.45065789 0.56907895 0.45285088 0.56926170 0.45312500 0.56926170 0.45504386 0.56944444 0.45531798 0.56944444 0.45751096 0.56962719 0.45778509 0.56962719 0.45997807 0.56980994 0.46025219 0.56980994 0.46244518 0.56999269 0.46271930 0.56999269 0.46463816 0.57017544 0.46491228 0.57017544 0.46710526 0.57035819 0.46737939 0.57035819 0.46820175 0.57054094 0.46847588 0.57054094 0.46929825 0.57072368 0.46957237 0.57072368 0.47039474 0.57090643 0.47066886 0.57090643 0.47149123 0.57108918 0.47176535 0.57108918 0.47258772 0.57127193 0.47286184 0.57127193 0.47368421 0.57145468 0.47395833 0.57145468 0.47478070 0.57163743 0.47505482 0.57163743 0.47587719 0.57182018 0.47615132 0.57182018 0.47724781 0.57200292 0.47752193 0.57200292 0.47834430 0.57218567 0.47861842 0.57218567 0.47944079 0.57236842 0.47971491 0.57236842 0.48053728 0.57255117 0.48081140 0.57255117 0.48163377 0.57273392 0.48190789 0.57273392 0.48273026 0.57291667 0.48300439 0.57291667 0.48382675 0.57309942 0.48410088 0.57309942 0.48492325 0.57328216 0.48519737 0.57328216 0.48601974 0.57346491 0.48629386 0.57346491 0.48711623 0.57364766 0.48739035 0.57364766 0.48821272 0.57383041 0.48848684 0.57383041 0.48958333 0.57401316 0.48985746 0.57401316 0.49067982 0.57419591 0.49095395 0.57419591 0.49177632 0.57437865 0.49205044 0.57437865 0.49287281 0.57456140 0.49314693 0.57456140 0.49396930 0.57474415 0.49424342 0.57474415 0.49506579 0.57492690 0.49533991 0.57492690 0.49616228 0.57510965 0.49643640 0.57510965 0.49725877 0.57529240 0.49753289 0.57529240 0.49835526 0.57547515 0.49862939 0.57547515 0.49945175 0.57565789 0.49972588 0.57565789 0.50054825 0.57584064 0.50082237 0.57584064 0.50191886 0.57602339 0.50219298 0.57602339 0.50301535 0.57620614 0.50328947 0.57620614 0.50411184 0.57638889 0.50438596 0.57638889 0.50520833 0.57657164 0.50548246 0.57657164 0.50630482 0.57675439 0.50657895 0.57675439 0.50740132 0.57693713 0.50767544 0.57693713 0.50849781 0.57711988 0.50877193 0.57711988 0.50959430 0.57730263 0.50986842 0.57730263 0.51069079 0.58753655 0.51069079 0.58753655 0.50877193 0.58735380 0.50849781 0.58735380 0.50575658 0.58717105 0.50548246 0.58717105 0.50274123 0.58698830 0.50246711 0.58698830 0.49972588 0.58680556 0.49945175 0.58680556 0.49671053 0.58662281 0.49643640 0.58662281 0.49369518 0.58644006 0.49342105 0.58644006 0.49067982 0.58625731 0.49040570 0.58625731 0.48766447 0.58607456 0.48739035 0.58607456 0.48464912 0.58589181 0.48437500 0.58589181 0.48163377 0.58570906 0.48135965 0.58570906 0.47861842 0.58552632 0.47834430 0.58552632 0.47560307 0.58534357 0.47532895 0.58534357 0.47286184 0.58516082 0.47258772 0.58516082 0.46984649 0.58497807 0.46957237 0.58497807 0.46683114 0.58479532 0.46655702 0.58479532 0.46381579 0.58461257 0.46354167 0.58461257 0.46080044 0.58442982 0.46052632 0.58442982 0.45778509 0.58424708 0.45751096 0.58424708 0.45476974 0.58406433 0.45449561 0.58406433 0.45175439 0.58388158 0.45148026 0.58388158 0.44873904 0.58369883 0.44846491 0.58369883 0.44572368 0.58351608 0.44544956 0.58351608 0.44270833 0.58333333 0.44243421 0.58333333 0.43969298 0.58315058 0.43941886 0.58315058 0.43667763 0.58296784 0.43640351 0.58296784 0.43366228 0.58278509 0.4 ...
#   0 0.38322368 0.34347588 0.38304094 0.34375000 0.38176170 0.34375000 0.38157895 0.34402412 0.37481725 0.34402412 0.37463450 0.34429825 0.36933480 0.34429825 0.36915205 0.34457237 0.36714181 0.34457237 0.36695906 0.34484649 0.35233918 0.34484649 0.35215643 0.34512061 0.35105994 0.34512061 0.35087719 0.34539474 0.34959795 0.34539474 0.34941520 0.34566886 0.34649123 0.34566886 0.34630848 0.34594298 0.34484649 0.34594298 0.34466374 0.34621711 0.34393275 0.34621711 0.34375000 0.34649123 0.34320175 0.34649123 0.34301901 0.34676535 0.34228801 0.34676535 0.34210526 0.34703947 0.34137427 0.34703947 0.34119152 0.34731360 0.34046053 0.34731360 0.34027778 0.34758772 0.33936404 0.34758772 0.33918129 0.34786184 0.33826754 0.34786184 0.33808480 0.34813596 0.33753655 0.34813596 0.33735380 0.34841009 0.33698830 0.34841009 0.33680556 0.34868421 0.33662281 0.34868421 0.33644006 0.34895833 0.33625731 0.34895833 0.33607456 0.34923246 0.33570906 0.34923246 0.33552632 0.34950658 0.33534357 0.34950658 0.33516082 0.34978070 0.33497807 0.34978070 0.33479532 0.35005482 0.33461257 0.35005482 0.33442982 0.35032895 0.33424708 0.35032895 0.33406433 0.35060307 0.33388158 0.35060307 0.33369883 0.35087719 0.33351608 0.35087719 0.33333333 0.35115132 0.33315058 0.35115132 0.33296784 0.35142544 0.33278509 0.35142544 0.33260234 0.35169956 0.33241959 0.35169956 0.33223684 0.35197368 0.33205409 0.35197368 0.33187135 0.35224781 0.33168860 0.35224781 0.33150585 0.35252193 0.33132310 0.35252193 0.33114035 0.35279605 0.33077485 0.35279605 0.33059211 0.35307018 0.33040936 0.35307018 0.32986111 0.35389254 0.32967836 0.35389254 0.32931287 0.35444079 0.32931287 0.35471491 0.32858187 0.35581140 0.32858187 0.35608553 0.32785088 0.35718202 0.32785088 0.35745614 0.32748538 0.35800439 0.32748538 0.35827851 0.32730263 0.35855263 0.32730263 0.35882675 0.32693713 0.35937500 0.32693713 0.35964912 0.32675439 0.35992325 0.32675439 0.36019737 0.32657164 0.36047149 0.32657164 0.36074561 0.32638889 0.36101974 0.32638889 0.36129386 0.32602339 0.36184211 0.32602339 0.36211623 0.32584064 0.36239035 0.32584064 0.36266447 0.32565789 0.36293860 0.32565789 0.36321272 0.32529240 0.36376096 0.32529240 0.36403509 0.32510965 0.36430921 0.32510965 0.36458333 0.32492690 0.36485746 0.32492690 0.36513158 0.32474415 0.36540570 0.32474415 0.36595395 0.32456140 0.36622807 0.32456140 0.36677632 0.32437865 0.36705044 0.32437865 0.36732456 0.32419591 0.36759868 0.32419591 0.36787281 0.32401316 0.36814693 0.32401316 0.36842105 0.32383041 0.36869518 0.32383041 0.36924342 0.32364766 0.36951754 0.32364766 0.36979167 0.32346491 0.37006579 0.32346491 0.37033991 0.32328216 0.37061404 0.32328216 0.37088816 0.32309942 0.37116228 0.32309942 0.37143640 0.32291667 0.37171053 0.32291667 0.37198465 0.32273392 0.37225877 0.32273392 0.37253289 0.32255117 0.37280702 0.32255117 0.37335526 0.32236842 0.37362939 0.32236842 0.37390351 0.32218567 0.37417763 0.32218567 0.37445175 0.32200292 0.37472588 0.32200292 0.37500000 0.32182018 0.37527412 0.32182018 0.37554825 0.32163743 0.37582237 0.32163743 0.37637061 0.32145468 0.37664474 0.32145468 0.37746711 0.32127193 0.37774123 0.32127193 0.37856360 0.32108918 0.37883772 0.32108918 0.37966009 0.32090643 0.37993421 0.32090643 0.38103070 0.32072368 0.38130482 0.32072368 0.38185307 0.32054094 0.38212719 0.32054094 0.38294956 0.32035819 0.38322368 0.32035819 0.38377193 0.32017544 0.38404605 0.32017544 0.38486842 0.31999269 0.38514254 0.31999269 0.38596491 0.31980994 0.38623904 0.31980994 0.38706140 0.31962719 0.38733553 0.31962719 0.38788377 0.31944444 0.38815789 0.31944444 0.38898026 0.31926170 0.38925439 0.31926170 0.39007675 0.31907895 0.39035088 0.31907895 0.39117325 0.31889620 0.39144737 0.31889620 0.39199561 0.31871345 0.39226974 0.31871345 0.39309211 0.31853070 0.39336623 0.31853070 0.39391447 0.31834795 0.39418860 0.31834795 0.39473684 0.31816520 0.39501096 0.31816520 0.39555921 0.31798246 0.39583333 0.31798246 0.39638158 0.31779971 0.39665570 0.31779971 0.39775219 0.31761696 0.3 ...
#   7 0.11239035 0.71244518 0.11239035 0.71299342 0.11220760 0.71326754 0.11220760 0.71408991 0.11202485 0.71436404 0.11202485 0.71491228 0.11184211 0.71518640 0.11184211 0.71600877 0.11165936 0.71628289 0.11165936 0.71710526 0.11147661 0.71737939 0.11147661 0.71820175 0.11129386 0.71847588 0.11129386 0.71929825 0.11111111 0.71957237 0.11111111 0.72012061 0.11092836 0.72039474 0.11092836 0.72121711 0.11074561 0.72149123 0.11074561 0.72231360 0.11056287 0.72258772 0.11056287 0.72341009 0.11038012 0.72368421 0.11038012 0.72423246 0.11019737 0.72450658 0.11019737 0.72532895 0.11001462 0.72560307 0.11001462 0.72642544 0.10983187 0.72669956 0.10983187 0.72752193 0.10964912 0.72779605 0.10964912 0.72834430 0.10946637 0.72861842 0.10946637 0.72944079 0.10928363 0.72971491 0.10928363 0.73053728 0.10910088 0.73081140 0.10910088 0.73163377 0.10891813 0.73190789 0.10891813 0.73273026 0.10873538 0.73300439 0.10873538 0.73355263 0.10855263 0.73382675 0.10855263 0.73464912 0.10836988 0.73492325 0.10836988 0.73574561 0.10818713 0.73601974 0.10818713 0.73684211 0.10800439 0.73711623 0.10800439 0.73766447 0.10782164 0.73793860 0.10782164 0.73876096 0.10763889 0.73903509 0.10763889 0.73985746 0.10745614 0.74013158 0.10745614 0.74095395 0.10727339 0.74122807 0.10727339 0.74150219 0.10745614 0.74177632 0.10745614 0.74259868 0.10763889 0.74287281 0.10763889 0.74342105 0.10782164 0.74369518 0.10782164 0.74451754 0.10800439 0.74479167 0.10800439 0.74561404 0.10818713 0.74588816 0.10818713 0.74643640 0.10836988 0.74671053 0.10836988 0.74753289 0.10855263 0.74780702 0.10855263 0.74862939 0.10873538 0.74890351 0.10873538 0.74945175 0.10891813 0.74972588 0.10891813 0.75054825 0.10910088 0.75082237 0.10910088 0.75137061 0.10928363 0.75164474 0.10928363 0.75246711 0.10946637 0.75274123 0.10946637 0.75356360 0.10964912 0.75383772 0.10964912 0.75438596 0.10983187 0.75466009 0.10983187 0.75548246 0.11001462 0.75575658 0.11001462 0.75657895 0.11019737 0.75685307 0.11019737 0.75740132 0.11038012 0.75767544 0.11038012 0.75849781 0.11056287 0.75877193 0.11056287 0.75959430 0.11074561 0.75986842 0.11074561 0.76041667 0.11092836 0.76069079 0.11092836 0.76151316 0.11111111 0.76178728 0.11111111 0.76260965 0.11129386 0.76288377 0.11129386 0.76343202 0.11147661 0.76370614 0.11147661 0.76452851 0.11165936 0.76480263 0.11165936 0.76535088 0.11184211 0.76562500 0.11184211 0.76644737 0.11202485 0.76672149 0.11202485 0.76754386 0.11220760 0.76781798 0.11220760 0.76836623 0.11239035 0.76864035 0.11239035 0.76946272 0.11275585 0.76946272 0.11293860 0.76973684 0.11312135 0.76973684 0.11330409 0.77001096 0.11366959 0.77001096 0.11385234 0.77028509 0.11421784 0.77028509 0.11440058 0.77055921 0.11476608 0.77055921 0.11494883 0.77083333 0.11531433 0.77083333 0.11549708 0.77110746 0.11586257 0.77110746 0.11604532 0.77138158 0.11641082 0.77138158 0.11659357 0.77165570 0.11695906 0.77165570 0.11714181 0.77192982 0.11750731 0.77192982 0.11769006 0.77220395 0.11805556 0.77220395 0.11823830 0.77247807 0.11860380 0.77247807 0.11878655 0.77275219 0.11896930 0.77275219 0.11915205 0.77302632 0.11951754 0.77302632 0.11970029 0.77330044 0.12006579 0.77330044 0.12024854 0.77357456 0.12061404 0.77357456 0.12079678 0.77384868 0.12116228 0.77384868 0.12134503 0.77412281 0.12171053 0.77412281 0.12189327 0.77439693 0.12225877 0.77439693 0.12244152 0.77467105 0.12280702 0.77467105 0.12298977 0.77494518 0.12335526 0.77494518 0.12353801 0.77521930 0.12390351 0.77521930 0.12408626 0.77549342 0.12445175 0.77549342 0.12463450 0.77576754 0.12500000 0.77576754 0.12518275 0.77604167 0.12536550 0.77604167 0.12554825 0.77631579 0.12591374 0.77631579 0.12609649 0.77658991 0.12646199 0.77658991 0.12664474 0.77686404 0.12701023 0.77686404 0.12719298 0.77713816 0.12755848 0.77713816 0.12774123 0.77741228 0.12810673 0.77741228 0.12828947 0.77768640 0.12865497 0.77768640 0.12883772 0.77796053 0.12920322 0.77796053 0.12938596 0.77823465 0.12975146 0.77823465 0.12993421 0.77850877 0.13029971 0.77850877 0.13048246 0.7 ...
# Testing annotation for: p222_M_28_001.jpg
# Detected annotation format: yolo
# Annotation content (first 3 lines):
#   1 0.65200617 0.34693287 0.65181327 0.34722222 0.65084877 0.34722222 0.65065586 0.34751157 0.64969136 0.34751157 0.64949846 0.34780093 0.64853395 0.34780093 0.64834105 0.34809028 0.64737654 0.34809028 0.64718364 0.34837963 0.64621914 0.34837963 0.64602623 0.34866898 0.64506173 0.34866898 0.64486883 0.34895833 0.64390432 0.34895833 0.64371142 0.34924769 0.64274691 0.34924769 0.64255401 0.34953704 0.64158951 0.34953704 0.64139660 0.34982639 0.64043210 0.34982639 0.64023920 0.35011574 0.63946759 0.35011574 0.63869599 0.35127315 0.63850309 0.35127315 0.63252315 0.36024306 0.63233025 0.36024306 0.62712191 0.36805556 0.62731481 0.36834491 0.62750772 0.36834491 0.62770062 0.36863426 0.62789352 0.36863426 0.62808642 0.36892361 0.62827932 0.36892361 0.62847222 0.36921296 0.62866512 0.36921296 0.62885802 0.36950231 0.62905093 0.36950231 0.62924383 0.36979167 0.62943673 0.36979167 0.62962963 0.37008102 0.62982253 0.37008102 0.63001543 0.37037037 0.63020833 0.37037037 0.63040123 0.37065972 0.63059414 0.37065972 0.63078704 0.37094907 0.63097994 0.37094907 0.63117284 0.37123843 0.63136574 0.37123843 0.63155864 0.37152778 0.63175154 0.37152778 0.63194444 0.37181713 0.63213735 0.37181713 0.63233025 0.37210648 0.63252315 0.37210648 0.63271605 0.37239583 0.63290895 0.37239583 0.63310185 0.37268519 0.63329475 0.37268519 0.63368056 0.37326389 0.63387346 0.37326389 0.63406636 0.37355324 0.63425926 0.37355324 0.63445216 0.37384259 0.63464506 0.37384259 0.63483796 0.37413194 0.63503086 0.37413194 0.63522377 0.37442130 0.63541667 0.37442130 0.63560957 0.37471065 0.63580247 0.37471065 0.63599537 0.37500000 0.63618827 0.37500000 0.63638117 0.37528935 0.63657407 0.37528935 0.63676698 0.37557870 0.63695988 0.37557870 0.63715278 0.37586806 0.63734568 0.37586806 0.63753858 0.37615741 0.63773148 0.37615741 0.63792438 0.37644676 0.63811728 0.37644676 0.63831019 0.37673611 0.63850309 0.37673611 0.63869599 0.37702546 0.63888889 0.37702546 0.63908179 0.37731481 0.63927469 0.37731481 0.63946759 0.37760417 0.63966049 0.37760417 0.63985340 0.37789352 0.64004630 0.37789352 0.64043210 0.37847222 0.64062500 0.37847222 0.64081790 0.37876157 0.64101080 0.37876157 0.64120370 0.37905093 0.64139660 0.37905093 0.64158951 0.37934028 0.64274691 0.37934028 0.64293981 0.37962963 0.64409722 0.37962963 0.64429012 0.37991898 0.64544753 0.37991898 0.64564043 0.38020833 0.64699074 0.38020833 0.64718364 0.38049769 0.64834105 0.38049769 0.64853395 0.38078704 0.64969136 0.38078704 0.64988426 0.38107639 0.65104167 0.38107639 0.65123457 0.38136574 0.65239198 0.38136574 0.65258488 0.38165509 0.65393519 0.38165509 0.65412809 0.38194444 0.65528549 0.38194444 0.65547840 0.38223380 0.65663580 0.38223380 0.65682870 0.38252315 0.65760031 0.38252315 0.65760031 0.38223380 0.65779321 0.38194444 0.65779321 0.38136574 0.65798611 0.38107639 0.65798611 0.38020833 0.65817901 0.37991898 0.65817901 0.37934028 0.65837191 0.37905093 0.65837191 0.37818287 0.65856481 0.37789352 0.65856481 0.37731481 0.65875772 0.37702546 0.65875772 0.37615741 0.65895062 0.37586806 0.65895062 0.37528935 0.65914352 0.37500000 0.65914352 0.37413194 0.65933642 0.37384259 0.65933642 0.37297454 0.65952932 0.37268519 0.65952932 0.37210648 0.65972222 0.37181713 0.65972222 0.37094907 0.65991512 0.37065972 0.65991512 0.37008102 0.66010802 0.36979167 0.66010802 0.36892361 0.66030093 0.36863426 0.66030093 0.36805556 0.66049383 0.36776620 0.66049383 0.36689815 0.66068673 0.36660880 0.66068673 0.36603009 0.66087963 0.36574074 0.66087963 0.36487269 0.66107253 0.36458333 0.66107253 0.36400463 0.66126543 0.36371528 0.66126543 0.36284722 0.66145833 0.36255787 0.66145833 0.36168981 0.66165123 0.36140046 0.66165123 0.36053241 0.65760031 0.35445602 0.65760031 0.35416667 0.65316358 0.34751157 0.65316358 0.34722222 0.65297068 0.34693287
#   1 0.71662809 0.35821759 0.71489198 0.36082176 0.71489198 0.36111111 0.71334877 0.36342593 0.71334877 0.36371528 0.71180556 0.36603009 0.71180556 0.36631944 0.71026235 0.36863426 0.71026235 0.36892361 0.70871914 0.37123843 0.70871914 0.37152778 0.70736883 0.37355324 0.70736883 0.37413194 0.70756173 0.37442130 0.70756173 0.37500000 0.70775463 0.37528935 0.70775463 0.37557870 0.70794753 0.37586806 0.70794753 0.37644676 0.70814043 0.37673611 0.70814043 0.37731481 0.70833333 0.37760417 0.70833333 0.37789352 0.70852623 0.37818287 0.70852623 0.37876157 0.70871914 0.37905093 0.70871914 0.37962963 0.70891204 0.37991898 0.70891204 0.38020833 0.70910494 0.38049769 0.70910494 0.38107639 0.70929784 0.38136574 0.70929784 0.38194444 0.70949074 0.38223380 0.70949074 0.38252315 0.70968364 0.38281250 0.70968364 0.38339120 0.70987654 0.38368056 0.70987654 0.38425926 0.71006944 0.38454861 0.71006944 0.38483796 0.71026235 0.38512731 0.71026235 0.38570602 0.71045525 0.38599537 0.71045525 0.38628472 0.71064815 0.38657407 0.71064815 0.38715278 0.71084105 0.38744213 0.71084105 0.38802083 0.71103395 0.38831019 0.71103395 0.38859954 0.71122685 0.38888889 0.71122685 0.38946759 0.71141975 0.38975694 0.71141975 0.39033565 0.71161265 0.39062500 0.71161265 0.39091435 0.71180556 0.39120370 0.71180556 0.39149306 0.71199846 0.39178241 0.71277006 0.39178241 0.71296296 0.39207176 0.71373457 0.39207176 0.71392747 0.39236111 0.71489198 0.39236111 0.71508488 0.39265046 0.71585648 0.39265046 0.71604938 0.39293981 0.71682099 0.39293981 0.71701389 0.39322917 0.71778549 0.39322917 0.71797840 0.39351852 0.71894290 0.39351852 0.71913580 0.39380787 0.71990741 0.39380787 0.72010031 0.39409722 0.72087191 0.39409722 0.72106481 0.39438657 0.72183642 0.39438657 0.72202932 0.39467593 0.72299383 0.39467593 0.72318673 0.39496528 0.72395833 0.39496528 0.72415123 0.39525463 0.72492284 0.39525463 0.72511574 0.39554398 0.72588735 0.39554398 0.72608025 0.39583333 0.72704475 0.39583333 0.72723765 0.39612269 0.72800926 0.39612269 0.72820216 0.39641204 0.72897377 0.39641204 0.72916667 0.39670139 0.72935957 0.39670139 0.72935957 0.39612269 0.72955247 0.39583333 0.72955247 0.39525463 0.72974537 0.39496528 0.72974537 0.39438657 0.72993827 0.39409722 0.72993827 0.39351852 0.73013117 0.39322917 0.73013117 0.39265046 0.73032407 0.39236111 0.73032407 0.39207176 0.73051698 0.39178241 0.73051698 0.39120370 0.73070988 0.39091435 0.73070988 0.39033565 0.73090278 0.39004630 0.73090278 0.38946759 0.73109568 0.38917824 0.73109568 0.38859954 0.73128858 0.38831019 0.73128858 0.38773148 0.73148148 0.38744213 0.73148148 0.38686343 0.73167438 0.38657407 0.73167438 0.38599537 0.73186728 0.38570602 0.73186728 0.38512731 0.73206019 0.38483796 0.73206019 0.38425926 0.73225309 0.38396991 0.73225309 0.38339120 0.73244599 0.38310185 0.73244599 0.38281250 0.73263889 0.38252315 0.73263889 0.38194444 0.73283179 0.38165509 0.73283179 0.38107639 0.73302469 0.38078704 0.73302469 0.37991898 0.73283179 0.37962963 0.73283179 0.37876157 0.73263889 0.37847222 0.73263889 0.37731481 0.73244599 0.37702546 0.73244599 0.37586806 0.73225309 0.37557870 0.73225309 0.37471065 0.73206019 0.37442130 0.73206019 0.37326389 0.73186728 0.37297454 0.73186728 0.37210648 0.73167438 0.37181713 0.73167438 0.37065972 0.73148148 0.37037037 0.73148148 0.36950231 0.73128858 0.36921296 0.73128858 0.36805556 0.73109568 0.36776620 0.73109568 0.36689815 0.73090278 0.36660880 0.73090278 0.36545139 0.73070988 0.36545139 0.73051698 0.36516204 0.73013117 0.36516204 0.72993827 0.36487269 0.72955247 0.36487269 0.72935957 0.36458333 0.72897377 0.36458333 0.72878086 0.36429398 0.72839506 0.36429398 0.72820216 0.36400463 0.72781636 0.36400463 0.72762346 0.36371528 0.72743056 0.36371528 0.72723765 0.36342593 0.72685185 0.36342593 0.72665895 0.36313657 0.72627315 0.36313657 0.72608025 0.36284722 0.72569444 0.36284722 0.72550154 0.36255787 0.72511574 0.36255787 0.72492284 0.36226852 0.72453704 0.36226852 0.72434414 0.36197917 0.72395833 0.36197917 0.72376543 0.3 ...
#   0 0.56385031 0.35300926 0.56365741 0.35329861 0.56327160 0.35329861 0.56307870 0.35358796 0.56269290 0.35358796 0.56250000 0.35387731 0.56192130 0.35387731 0.56172840 0.35416667 0.56114969 0.35416667 0.56095679 0.35445602 0.55999228 0.35445602 0.55979938 0.35474537 0.55844907 0.35474537 0.55825617 0.35503472 0.55671296 0.35503472 0.55652006 0.35532407 0.55594136 0.35532407 0.55574846 0.35561343 0.55555556 0.35561343 0.55536265 0.35590278 0.55497685 0.35590278 0.55478395 0.35619213 0.55459105 0.35619213 0.55439815 0.35648148 0.55401235 0.35648148 0.55381944 0.35677083 0.55362654 0.35677083 0.55324074 0.35734954 0.55285494 0.35734954 0.55266204 0.35763889 0.55246914 0.35763889 0.55227623 0.35792824 0.55169753 0.35792824 0.55150463 0.35821759 0.55092593 0.35821759 0.55073302 0.35850694 0.54996142 0.35850694 0.54976852 0.35879630 0.54918981 0.35879630 0.54899691 0.35908565 0.54880401 0.35908565 0.54861111 0.35937500 0.54822531 0.35937500 0.54803241 0.35966435 0.54783951 0.35966435 0.54764660 0.35995370 0.54745370 0.35995370 0.54726080 0.36024306 0.54687500 0.36024306 0.54668210 0.36053241 0.54629630 0.36053241 0.54610340 0.36082176 0.54571759 0.36082176 0.54552469 0.36111111 0.54513889 0.36111111 0.54494599 0.36140046 0.54456019 0.36140046 0.54436728 0.36168981 0.54398148 0.36168981 0.54378858 0.36197917 0.54359568 0.36197917 0.54340278 0.36226852 0.54320988 0.36226852 0.54301698 0.36255787 0.54263117 0.36255787 0.54243827 0.36284722 0.54224537 0.36284722 0.54205247 0.36313657 0.54166667 0.36313657 0.54147377 0.36342593 0.54128086 0.36342593 0.54108796 0.36371528 0.54089506 0.36371528 0.54070216 0.36400463 0.54050926 0.36400463 0.54012346 0.36458333 0.53993056 0.36458333 0.53915895 0.36574074 0.53915895 0.36603009 0.53780864 0.36805556 0.53761574 0.36805556 0.53684414 0.36921296 0.53665123 0.36921296 0.53587963 0.37037037 0.53568673 0.37037037 0.53549383 0.37065972 0.53530093 0.37065972 0.53491512 0.37123843 0.53472222 0.37123843 0.53452932 0.37152778 0.53414352 0.37152778 0.53395062 0.37181713 0.53375772 0.37181713 0.53356481 0.37210648 0.53337191 0.37210648 0.53260031 0.37326389 0.53260031 0.37355324 0.53240741 0.37384259 0.53240741 0.37413194 0.53202160 0.37471065 0.53202160 0.37500000 0.53086420 0.37673611 0.53067130 0.37673611 0.52912809 0.37905093 0.52893519 0.37905093 0.52681327 0.38223380 0.52662037 0.38223380 0.52623457 0.38281250 0.52604167 0.38281250 0.52546296 0.38368056 0.52527006 0.38368056 0.52469136 0.38454861 0.52469136 0.38483796 0.52430556 0.38541667 0.52430556 0.38570602 0.52391975 0.38628472 0.52391975 0.38657407 0.52353395 0.38715278 0.52353395 0.38744213 0.52314815 0.38802083 0.52314815 0.38831019 0.52276235 0.38888889 0.52276235 0.38917824 0.52199074 0.39033565 0.52199074 0.39062500 0.52141204 0.39149306 0.52141204 0.39178241 0.52083333 0.39265046 0.52083333 0.39293981 0.52006173 0.39409722 0.52006173 0.39438657 0.51774691 0.39785880 0.51755401 0.39785880 0.51716821 0.39843750 0.51697531 0.39843750 0.51620370 0.39959491 0.51620370 0.39988426 0.51562500 0.40075231 0.51562500 0.40104167 0.51543210 0.40133102 0.51543210 0.40190972 0.51523920 0.40219907 0.51523920 0.40248843 0.51504630 0.40277778 0.51504630 0.40306713 0.51466049 0.40364583 0.51466049 0.40393519 0.51446759 0.40422454 0.51446759 0.40451389 0.51427469 0.40480324 0.51427469 0.40509259 0.51350309 0.40625000 0.51350309 0.40653935 0.51292438 0.40740741 0.51273148 0.40740741 0.50887346 0.41319444 0.50887346 0.41348380 0.50694444 0.41637731 0.50694444 0.41666667 0.50636574 0.41753472 0.50636574 0.41782407 0.50597994 0.41840278 0.50597994 0.41869213 0.50540123 0.41956019 0.50540123 0.41984954 0.50520833 0.42013889 0.50520833 0.42042824 0.50501543 0.42071759 0.50501543 0.42100694 0.50482253 0.42129630 0.50482253 0.42158565 0.50462963 0.42187500 0.50462963 0.42216435 0.50443673 0.42245370 0.50443673 0.42303241 0.50424383 0.42332176 0.50424383 0.42361111 0.50385802 0.42418981 0.50385802 0.42447917 0.50366512 0.42476852 0.50366512 0.42505787 0.50327932 0.4 ...
# Testing annotation for: p135_F_37_003.jpg
# Detected annotation format: yolo
# Annotation content (first 3 lines):
#   0 0.62225877 0.19654605 0.62225877 0.19682018 0.62171053 0.19764254 0.62171053 0.19791667 0.62097953 0.19901316 0.62097953 0.19928728 0.62043129 0.20010965 0.62043129 0.20038377 0.61988304 0.20120614 0.61988304 0.20148026 0.61933480 0.20230263 0.61933480 0.20257675 0.61878655 0.20339912 0.61878655 0.20367325 0.61823830 0.20449561 0.61823830 0.20476974 0.61769006 0.20559211 0.61769006 0.20586623 0.61695906 0.20696272 0.61695906 0.20723684 0.61641082 0.20805921 0.61641082 0.20833333 0.61586257 0.20915570 0.61586257 0.20942982 0.61531433 0.21025219 0.61531433 0.21052632 0.61476608 0.21134868 0.61476608 0.21162281 0.61421784 0.21244518 0.61421784 0.21271930 0.61366959 0.21354167 0.61366959 0.21381579 0.61293860 0.21491228 0.61293860 0.21518640 0.61239035 0.21600877 0.61239035 0.21628289 0.61184211 0.21710526 0.61184211 0.21737939 0.61129386 0.21820175 0.61129386 0.21847588 0.61074561 0.21929825 0.61074561 0.21957237 0.61019737 0.22039474 0.61019737 0.22066886 0.60964912 0.22149123 0.60964912 0.22176535 0.60891813 0.22286184 0.60891813 0.22313596 0.60836988 0.22395833 0.60836988 0.22423246 0.60782164 0.22505482 0.60782164 0.22532895 0.60727339 0.22615132 0.60727339 0.22642544 0.60672515 0.22724781 0.60672515 0.22752193 0.60617690 0.22834430 0.60617690 0.22861842 0.60562865 0.22944079 0.60562865 0.22971491 0.60489766 0.23081140 0.60489766 0.23108553 0.60434942 0.23190789 0.60434942 0.23218202 0.60380117 0.23300439 0.60380117 0.23327851 0.60325292 0.23410088 0.60325292 0.23437500 0.60270468 0.23519737 0.60270468 0.23547149 0.60215643 0.23629386 0.60215643 0.23656798 0.60160819 0.23739035 0.60160819 0.23766447 0.60087719 0.23876096 0.60087719 0.23903509 0.60032895 0.23985746 0.60032895 0.24013158 0.59978070 0.24095395 0.59978070 0.24122807 0.59923246 0.24205044 0.59923246 0.24232456 0.59868421 0.24314693 0.59868421 0.24342105 0.59813596 0.24424342 0.59813596 0.24451754 0.59758772 0.24533991 0.59758772 0.24561404 0.59685673 0.24671053 0.59685673 0.24698465 0.59630848 0.24780702 0.59630848 0.24808114 0.59576023 0.24890351 0.59576023 0.24917763 0.59521199 0.25000000 0.59521199 0.25027412 0.59466374 0.25109649 0.59466374 0.25137061 0.59411550 0.25219298 0.59411550 0.25246711 0.59356725 0.25328947 0.59356725 0.25356360 0.59283626 0.25466009 0.59283626 0.25493421 0.59228801 0.25575658 0.59228801 0.25630482 0.59210526 0.25657895 0.59210526 0.25712719 0.59192251 0.25740132 0.59192251 0.25794956 0.59173977 0.25822368 0.59173977 0.25904605 0.59155702 0.25932018 0.59155702 0.25986842 0.59137427 0.26014254 0.59137427 0.26069079 0.59119152 0.26096491 0.59119152 0.26178728 0.59100877 0.26206140 0.59100877 0.26260965 0.59082602 0.26288377 0.59082602 0.26343202 0.59064327 0.26370614 0.59064327 0.26452851 0.59046053 0.26480263 0.59046053 0.26535088 0.59027778 0.26562500 0.59027778 0.26617325 0.59009503 0.26644737 0.59009503 0.26726974 0.58991228 0.26754386 0.58991228 0.26809211 0.58972953 0.26836623 0.58972953 0.26891447 0.58954678 0.26918860 0.58954678 0.27001096 0.58936404 0.27028509 0.58936404 0.27083333 0.58918129 0.27110746 0.58918129 0.27165570 0.58899854 0.27192982 0.58899854 0.27275219 0.58881579 0.27302632 0.58881579 0.27357456 0.58863304 0.27384868 0.58863304 0.27439693 0.58845029 0.27467105 0.58845029 0.27549342 0.58826754 0.27576754 0.58826754 0.27631579 0.58808480 0.27658991 0.58808480 0.27713816 0.58790205 0.27741228 0.58790205 0.27823465 0.58771930 0.27850877 0.58771930 0.27905702 0.58753655 0.27933114 0.58753655 0.27987939 0.58735380 0.28015351 0.58735380 0.28097588 0.58717105 0.28125000 0.58717105 0.28179825 0.58698830 0.28207237 0.58698830 0.28262061 0.58680556 0.28289474 0.58680556 0.28371711 0.58662281 0.28399123 0.58662281 0.28453947 0.58644006 0.28481360 0.58644006 0.28536184 0.58625731 0.28563596 0.58625731 0.28645833 0.58607456 0.28673246 0.58607456 0.28728070 0.58589181 0.28755482 0.58589181 0.28810307 0.58570906 0.28837719 0.58570906 0.28919956 0.58607456 0.28974781 0.58607456 0.29002193 0.58625731 0.29029605 0.58625731 0.2 ...
#   0 0.54367690 0.12280702 0.54294591 0.12390351 0.54294591 0.12417763 0.54184942 0.12582237 0.54184942 0.12609649 0.54057018 0.12801535 0.54057018 0.12828947 0.53947368 0.12993421 0.53947368 0.13020833 0.53837719 0.13185307 0.53837719 0.13212719 0.53709795 0.13404605 0.53709795 0.13432018 0.53600146 0.13596491 0.53600146 0.13623904 0.53490497 0.13788377 0.53490497 0.13815789 0.53362573 0.14007675 0.53362573 0.14035088 0.53252924 0.14199561 0.53252924 0.14226974 0.53125000 0.14418860 0.53125000 0.14446272 0.53015351 0.14610746 0.53015351 0.14638158 0.52905702 0.14802632 0.52905702 0.14830044 0.52777778 0.15021930 0.52777778 0.15049342 0.52668129 0.15213816 0.52668129 0.15241228 0.52558480 0.15405702 0.52558480 0.15433114 0.52430556 0.15625000 0.52430556 0.15652412 0.52320906 0.15816886 0.52320906 0.15844298 0.52211257 0.16008772 0.52211257 0.16036184 0.52083333 0.16228070 0.52083333 0.16255482 0.52028509 0.16337719 0.52028509 0.16858553 0.52046784 0.16885965 0.52046784 0.17900219 0.52065058 0.17927632 0.52065058 0.18941886 0.52083333 0.18969298 0.52083333 0.19983553 0.52101608 0.20010965 0.52101608 0.20559211 0.52119883 0.20586623 0.52119883 0.20641447 0.52138158 0.20668860 0.52138158 0.20751096 0.52156433 0.20778509 0.52156433 0.20833333 0.52174708 0.20860746 0.52174708 0.20942982 0.52192982 0.20970395 0.52192982 0.21052632 0.52211257 0.21080044 0.52211257 0.21134868 0.52229532 0.21162281 0.52229532 0.21244518 0.52247807 0.21271930 0.52247807 0.21326754 0.52266082 0.21354167 0.52266082 0.21436404 0.52284357 0.21463816 0.52284357 0.21518640 0.52302632 0.21546053 0.52302632 0.21628289 0.52320906 0.21655702 0.52320906 0.21710526 0.52339181 0.21737939 0.52339181 0.21820175 0.52357456 0.21847588 0.52357456 0.21902412 0.52375731 0.21929825 0.52375731 0.22012061 0.52394006 0.22039474 0.52394006 0.22094298 0.52412281 0.22121711 0.52412281 0.22203947 0.52430556 0.22231360 0.52430556 0.22286184 0.52448830 0.22313596 0.52448830 0.22395833 0.52467105 0.22423246 0.52467105 0.22478070 0.52485380 0.22505482 0.52485380 0.22587719 0.52503655 0.22615132 0.52503655 0.22697368 0.52521930 0.22724781 0.52521930 0.22779605 0.52540205 0.22807018 0.52540205 0.22889254 0.52558480 0.22916667 0.52558480 0.22971491 0.52576754 0.22998904 0.52576754 0.23081140 0.52595029 0.23108553 0.52595029 0.23163377 0.52613304 0.23190789 0.52613304 0.23273026 0.52631579 0.23300439 0.52631579 0.23355263 0.52649854 0.23382675 0.52649854 0.23464912 0.52668129 0.23492325 0.52668129 0.23547149 0.52686404 0.23574561 0.52686404 0.23656798 0.52704678 0.23684211 0.52704678 0.23739035 0.52722953 0.23766447 0.52722953 0.23848684 0.52741228 0.23876096 0.52741228 0.23930921 0.52759503 0.23958333 0.52759503 0.24040570 0.52777778 0.24067982 0.52777778 0.24122807 0.52796053 0.24150219 0.52796053 0.24232456 0.52814327 0.24259868 0.52814327 0.24342105 0.52832602 0.24369518 0.52832602 0.24424342 0.52850877 0.24451754 0.52850877 0.24533991 0.52869152 0.24561404 0.52869152 0.24616228 0.52887427 0.24643640 0.52887427 0.24725877 0.52905702 0.24753289 0.52905702 0.24808114 0.52923977 0.24835526 0.52923977 0.24917763 0.52942251 0.24945175 0.52942251 0.25000000 0.52960526 0.25027412 0.52960526 0.25109649 0.52978801 0.25137061 0.52978801 0.25191886 0.52997076 0.25219298 0.52997076 0.25301535 0.53015351 0.25328947 0.53015351 0.25383772 0.53033626 0.25411184 0.53033626 0.25493421 0.53051901 0.25520833 0.53051901 0.25575658 0.53070175 0.25603070 0.53088450 0.25603070 0.53106725 0.25630482 0.53125000 0.25630482 0.53143275 0.25657895 0.53161550 0.25657895 0.53179825 0.25685307 0.53198099 0.25685307 0.53216374 0.25712719 0.53234649 0.25712719 0.53252924 0.25740132 0.53271199 0.25740132 0.53307749 0.25794956 0.53326023 0.25794956 0.53344298 0.25822368 0.53362573 0.25822368 0.53380848 0.25849781 0.53399123 0.25849781 0.53417398 0.25877193 0.53435673 0.25877193 0.53453947 0.25904605 0.53472222 0.25904605 0.53490497 0.25932018 0.53508772 0.25932018 0.53527047 0.25959430 0.53545322 0.25959430 0.53563596 0.2 ...
#   0 0.38651316 0.14912281 0.38614766 0.14967105 0.38596491 0.14967105 0.38578216 0.14994518 0.38559942 0.14994518 0.38523392 0.15049342 0.38505117 0.15049342 0.38486842 0.15076754 0.38468567 0.15076754 0.38450292 0.15104167 0.38432018 0.15104167 0.38395468 0.15158991 0.38377193 0.15158991 0.38358918 0.15186404 0.38340643 0.15186404 0.38304094 0.15241228 0.38285819 0.15241228 0.38267544 0.15268640 0.38249269 0.15268640 0.38212719 0.15323465 0.38194444 0.15323465 0.38176170 0.15350877 0.38157895 0.15350877 0.38121345 0.15405702 0.38103070 0.15405702 0.38084795 0.15433114 0.38066520 0.15433114 0.38048246 0.15460526 0.38029971 0.15460526 0.37993421 0.15515351 0.37975146 0.15515351 0.37956871 0.15542763 0.37938596 0.15542763 0.37902047 0.15597588 0.37883772 0.15597588 0.37865497 0.15625000 0.37847222 0.15625000 0.37810673 0.15679825 0.37792398 0.15679825 0.37774123 0.15707237 0.37755848 0.15707237 0.37737573 0.15734649 0.37719298 0.15734649 0.37682749 0.15789474 0.37664474 0.15789474 0.37646199 0.15816886 0.37627924 0.15816886 0.37591374 0.15871711 0.37573099 0.15871711 0.37554825 0.15899123 0.37536550 0.15899123 0.37500000 0.15953947 0.37481725 0.15953947 0.37463450 0.15981360 0.37445175 0.15981360 0.37408626 0.16036184 0.37390351 0.16036184 0.37372076 0.16063596 0.37353801 0.16063596 0.37335526 0.16091009 0.37317251 0.16091009 0.37280702 0.16145833 0.37262427 0.16145833 0.37244152 0.16173246 0.37225877 0.16173246 0.37189327 0.16228070 0.37171053 0.16228070 0.37152778 0.16255482 0.37134503 0.16255482 0.37097953 0.16310307 0.37079678 0.16310307 0.37061404 0.16337719 0.37043129 0.16337719 0.37006579 0.16392544 0.36988304 0.16392544 0.36970029 0.16419956 0.36951754 0.16419956 0.36933480 0.16447368 0.36915205 0.16447368 0.36878655 0.16502193 0.36860380 0.16502193 0.36842105 0.16529605 0.36823830 0.16529605 0.36787281 0.16584430 0.36769006 0.16584430 0.36750731 0.16611842 0.36732456 0.16611842 0.36695906 0.16666667 0.36677632 0.16666667 0.36659357 0.16694079 0.36641082 0.16694079 0.36622807 0.16721491 0.36604532 0.16721491 0.36567982 0.16776316 0.36549708 0.16776316 0.36531433 0.16803728 0.36513158 0.16803728 0.36476608 0.16858553 0.36458333 0.16858553 0.36440058 0.16885965 0.36421784 0.16885965 0.36385234 0.16940789 0.36366959 0.16940789 0.36348684 0.16968202 0.36330409 0.16968202 0.36293860 0.17023026 0.36275585 0.17023026 0.36257310 0.17050439 0.36239035 0.17050439 0.36220760 0.17077851 0.36202485 0.17077851 0.36165936 0.17132675 0.36147661 0.17132675 0.36129386 0.17160088 0.36111111 0.17160088 0.36074561 0.17214912 0.36056287 0.17214912 0.36038012 0.17242325 0.36019737 0.17242325 0.35983187 0.17297149 0.35964912 0.17297149 0.35946637 0.17324561 0.35928363 0.17324561 0.35910088 0.17351974 0.35891813 0.17351974 0.35855263 0.17406798 0.35836988 0.17406798 0.35818713 0.17434211 0.35800439 0.17434211 0.35800439 0.17461623 0.35763889 0.17516447 0.35763889 0.17543860 0.35745614 0.17571272 0.35745614 0.17598684 0.35727339 0.17626096 0.35727339 0.17653509 0.35690789 0.17708333 0.35690789 0.17735746 0.35672515 0.17763158 0.35672515 0.17790570 0.35654240 0.17817982 0.35654240 0.17845395 0.35617690 0.17900219 0.35617690 0.17927632 0.35599415 0.17955044 0.35599415 0.17982456 0.35581140 0.18009868 0.35581140 0.18037281 0.35544591 0.18092105 0.35544591 0.18119518 0.35526316 0.18146930 0.35526316 0.18174342 0.35489766 0.18229167 0.35489766 0.18256579 0.35471491 0.18283991 0.35471491 0.18311404 0.35453216 0.18338816 0.35453216 0.18366228 0.35416667 0.18421053 0.35416667 0.18448465 0.35398392 0.18475877 0.35398392 0.18503289 0.35380117 0.18530702 0.35380117 0.18558114 0.35343567 0.18612939 0.35343567 0.18640351 0.35325292 0.18667763 0.35325292 0.18695175 0.35307018 0.18722588 0.35307018 0.18750000 0.35270468 0.18804825 0.35270468 0.18832237 0.35252193 0.18859649 0.35252193 0.18887061 0.35233918 0.18914474 0.35233918 0.18941886 0.35197368 0.18996711 0.35197368 0.19024123 0.35179094 0.19051535 0.35179094 0.19078947 0.35160819 0.19106360 0.35160819 0.1 ...
# Training completed!
